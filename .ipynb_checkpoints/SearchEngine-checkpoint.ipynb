# %% [markdown]
# # Search within a pdf for a specific term

# %% [markdown]
# ### listing all the documents in the drive

# %%
# import required module
import os
import re
import PyPDF2 
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
for filename in os.listdir(directory):
    if not filename.startswith('~$') and filename.endswith('.pdf'):
        print(filename)
# Out:
# ISO_26262-1.pdf
# ISO_26262-10_Dez.-2018.pdf
# ISO_26262-11_Dez.-2018.pdf
# ISO_26262-12_Dez.-2018.pdf
# ISO_26262-3.pdf
# ISO_26262-4.pdf
# ISO_26262-6.pdf
# ISO_26262-7.pdf
# ISO_26262-8.pdf
# ISO_26262-9.pdf

# %% [markdown]
# ### Searching for a value in a specific pdf files

# %%
# import required module
import os
import re
import fitz
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-12_Dez.-2018.pdf'

# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        #print(type(text))
        #print(text)
        if pattern.search(text):
            print("Found the Text on page",i+1, "from the file :", filename)
# Out:
# Enter_the_text_to_Search_hereHazard analysis and risk assessment
# Found the Text on page 3 from the file : ISO_26262-12_Dez.-2018.pdf
# Found the Text on page 4 from the file : ISO_26262-12_Dez.-2018.pdf
# Found the Text on page 19 from the file : ISO_26262-12_Dez.-2018.pdf
# Found the Text on page 26 from the file : ISO_26262-12_Dez.-2018.pdf
# Found the Text on page 38 from the file : ISO_26262-12_Dez.-2018.pdf

# %% [markdown]
# ### Open a specific page from a file

# %%
def open_pdf(filename, page=1):
    return subprocess.Popen(["C:/Program Files (x86)/Adobe/Acrobat Reader DC/Reader/AcroRd32.exe", '/A', 'page={:d}'.format(page), filename], stdout=subprocess.PIPE)

# %%
import subprocess
process = open_pdf("C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-7.pdf", page=15)
process.wait()
# Out:
# 1

# %% [markdown]
# # Searching yithin docx files

# %%
# import required module
import os
import re
# assign directory
directory = 'C:/Users/Samar/Desktop/5BI4/Stage PFE/essay/Test'
 
# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
for filename in os.listdir(directory):
    if not filename.startswith('~$'):
        f = os.path.join(directory, filename)
    
    print(f)
    # checking if it is a file
    if os.path.isfile(f):
        document = Document(f)
        import re
        
        
        for para in document.paragraphs: 
        
        
            if pattern.search(para.text):
                print("Found the paragraph in this file" ,filename)
                print(para.text)
                break
       
        else:
                 print("Did not find the paragraph :(")

# %% [markdown]
# ### Search for the  specific requirements

# %%
# import required module
import os
import re
import PyPDF2 
import fitz
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-12_Dez.-2018.pdf'

# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        #print(type(text))
        #print(text)
        if pattern.search(text):
            print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                #print(substring)
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                #print(list[-1])
                T = listToString(list[-1])
                TT = (int(T))
                TT= TT+1
                TT = (str(TT))
                print(type(TT))
                pat = re.compile(T+".\d+\s"+"Work products")
                for i in range(0, page_count):
                    page = doc[i]
                    text = page.get_text("text")
                    list1 = pat.findall(str(text))
                    found3 = re.finditer(pat, text)
                    #print(list1)
                    res = []
                    for i in list1:
                        if i:
                            res.append(i)
                            #print(res)
                            resultFound = listToString(res)
                            print("Work Products:", resultFound)
                            PR = re.compile(r'\d+.\d+')
                            
                            list4 = PR.findall(str(resultFound))
                            
                            
                            
                            
                            for item in found3:
                                s = item.start()
                                e = item.end()
                                substring3 = text[s:e+300]
                                print(substring3.split(TT)[0])
                                p = re.compile(r'\d+.\d+.\d+')
                                list2 = p.findall(str(substring3))
                                print(list2)
                                TTT = listToString1(list2)
                                print("this is the list of digits:",TTT)
                                wp = listToString(list4)
                                Num = wp
                                print(Num)
                                Numbers = re.findall(Num+".\d", TTT)
                                print(type(Numbers))
                                
                                TTTT = listToString1(Numbers)
                                print(TTTT)
                                for x in Numbers:
                                    print(x)
                                    list2.remove(x)
                                print(list2)
                                for x in list2:
                                    patternWP = re.compile(x+"\s+.*\.")
                                    for i in range(0, 5):
                                        page = doc[i]
                                        text = page.get_text("text")
                                        list6 = patternWP.findall(str(text))
                                        #print(list6)
                                        res1 = []
                                        for i in list6:
                                            if i:
                                                res1.append(i)
                                                #print(res1)
                                                resultFound = listToString(res1)
                                                print(resultFound)
# Out:
# Enter_the_text_to_Search_hereSafety validation
# Found the Text on page 3 from the file : ISO_26262-12_Dez.-2018.pdf
# <class 'str'>
# Work Products: 10.5 Work products
# 10.5 Work products
# 10.5.1	 Safety	 validation	 specification	 including	 safety	 validation	 environment	 description
# resulting from requirements in 10.4.1 and 10.4.2.
# 10.5.2 Safety validation report resulting from requirements in 10.4.3 and 10.4.4.
#
# © ISO 2018 – All rights reserved
# 23
# Normen-Download-Beuth-Lisa D
# ['10.5.1', '10.4.1', '10.4.2', '10.5.2', '10.4.3', '10.4.4']
# this is the list of digits: 10.5.1 10.4.1 10.4.2 10.5.2 10.4.3 10.4.4
# 10.5
# <class 'list'>
# 10.5.1 10.5.2
# 10.5.1
# 10.5.2
# ['10.4.1', '10.4.2', '10.4.3', '10.4.4']
# 10.4.1 Safety validation environment ..........................................................................................................................
# 10.4.2 Specification of safety validation ....................................................................................................................
# 10.4.3 Execution of safety validation ............................................................................................................................
# 10.4.4 Evaluation ...........................................................................................................................................................................
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [16], in <cell line: 13>()
#      32 list = p.findall(str(substring))
#      33 #print(list[-1])
# ---> 34 T = listToString(list[-1])
#      35 TT = (int(T))
#      36 TT= TT+1
#
# IndexError: list index out of range

# %%
# Function to convert  
def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    
    # return string  
    return str1

# %%
# Function to convert  
def listToString1(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele+" "  
    
    # return string  
    return str1

# %% [markdown]
# ### hierarchy Extraction

# %% [markdown]
# #### 5 levels

# %%
# import required module
import os
import re
import PyPDF2 
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here: "))
for filename in os.listdir(directory):
    if not filename.startswith('~$') and filename.endswith('.pdf'):
        f = os.path.join(directory, filename)
        doc = fitz.open(f)
        page_count = len(doc)
        #print(page_count)
        for i in range(0, page_count):
            page = doc[i]
            text = page.get_text("text")
            found = re.finditer(pattern, text)
            #print(type(text))
            #print(text)
            if pattern.search(text):
                print("Found the Text on page",i+1, "from the file :", filename)
                #print(text)
                for item in found:
                    s = item.start()
                    e = item.end()
                    substring = text[s-900:e]
                    #print('THIS',substring)
                    #print(substring)
                    p5 = re.compile(r'\d+.\d+.\d+.\d+.\d+')
 
                    list5 = p5.findall(str(substring))

                    T = listToString(list5[-1])
 
                    print("This is list 5",list5,"Found the Text on page",i+1)

                    print("this is content 5: ",T)
#############################################level 4 ###########################################################################
                    pa4 = re.compile(r'\d+.\d+.\d+.\d+')
                    print("THIS IS OF A four DIGITS",pa4.findall(str(list5[-1])))
                    fourth = pa4.findall(str(list5[-1]))
                    TTTT = listToString(fourth)
                    print("this is content 4: ",TTTT)
                    pat = re.compile("\s"+TTTT+"\s+\D+\s+")
                    for i in range(0, page_count):
                        page = doc[i]
                        text = page.get_text("text")
                        found = re.finditer(pat, text)
                        if pat.search(text):
                            print("Found the Text on page",i+1)
                            list = pat.findall(str(text))
                            print("LEVEL 4:",list)
####################################level 3#####################################################################################
                    pa3 = re.compile(r'\d+.\d+.\d+')
                    print("THIS IS OF A three DIGITS",pa3.findall(str(list5[-1])))
                    third = pa3.findall(str(list5[-1]))
                    TTT = listToString(third)
                    print("this is content 3: ",TTT)
                    pat = re.compile("\s"+TTT+"\s+\D+\s+")
                    for i in range(0, 5):
                        page = doc[i]
                        text = page.get_text("text")
                        found = re.finditer(pat, text)
                        if pat.search(text):
                            print("Found the Text on page",i+1)
                            list = pat.findall(str(text))
                            print("LEVEL 3:",list)
##########################################################level 2###############################################################
                    pa2 = re.compile(r'\d+.\d+')
                    print("THIS IS OF A two DIGITS",pa2.findall(str(list5[-1])))
                    second = pa2.findall(str(list5[-1]))
                    TT = listToString(second[0])
                    print("this is content 2: ",TT)
                    pat = re.compile("\s"+TT+"\s+\D+\s+")
                    for i in range(0, 5):
                        page = doc[i]
                        text = page.get_text("text")
                        found = re.finditer(pat, text)
                        if pat.search(text):
                            print("Found the Text on page",i+1)
                            list = pat.findall(str(text))
                            print("LEVEL 2",list)

################################################level 1 ########################################################################

                    pa1 = re.compile(r'\d')
                    print("THIS IS OF A one DIGITS",pa1.findall(str(list5[-1])))
                    third = pa1.findall(str(list5[-1]))
                    T = listToString(third[0])
                    print("this is content 1: ",T)
                    pat = re.compile("\s"+T+"\s+\D+\s+")
                    for i in range(0, 5):
                        page = doc[i]
                        text = page.get_text("text")
                        #print(text)
                        found = re.finditer(pat, text)
                        #print(found)
                        if pat.search(text):
                            print("Found the Text on page",i+1)
                            list = pat.findall(str(text))
                            print("LEVEL 1:",list)
# Out:
# Enter_the_text_to_Search_here: PLD manufacturer also assumes the role of item integrator
# Found the Text on page 112 from the file : ISO_26262-11_Dez.-2018.pdf
# This is list 5 ['26262-2:2018', '26262-2:2018', '26262-2:2018', '5.3.1.3.3'] Found the Text on page 112
# this is content 5:  5.3.1.3.3
# THIS IS OF A four DIGITS ['5.3.1.3']
# this is content 4:  5.3.1.3
# Found the Text on page 111
# LEVEL 4: ['\n5.3.1.3 \nFunctional safety lifecycle tailoring for PLD\n']
# THIS IS OF A three DIGITS ['5.3.1']
# this is content 3:  5.3.1
# Found the Text on page 4
# LEVEL 3: ['\n5.3.1 \nAbout programmable logic devices ']
# THIS IS OF A two DIGITS ['5.3', '1.3']
# this is content 2:  5.3
# Found the Text on page 4
# LEVEL 2 ['\n5.3 \nProgrammable logic devices ']
# THIS IS OF A one DIGITS ['5', '3', '1', '3', '3']
# this is content 1:  5
# Found the Text on page 3
# LEVEL 1: ['\n5\t\nSpecific\tsemiconductor\ttechnologies\tand\tuse\tcases ']

# %% [markdown]
# #### Level of 4 digits

# %%
# import required module
import os
import re
import PyPDF2 
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here: "))
for filename in os.listdir(directory):
    if not filename.startswith('~$') and filename.endswith('.pdf'):
        f = os.path.join(directory, filename)
        doc = fitz.open(f)
        page_count = len(doc)
        #print(page_count)
        for i in range(0, page_count):
            page = doc[i]
            text = page.get_text("text")
            found = re.finditer(pattern, text)
            #print(type(text))
            #print(text)
            if pattern.search(text):
                print("Found the Text on page",i+1, "from the file :", filename)
                #print(text)
                for item in found:
                    s = item.start()
                    e = item.end()
                    substring = text[s-900:e]
                    #print('THIS',substring)
                    #print(substring)
                    p5 = re.compile(r'\d+.\d+.\d+.\d+.\d+\s+')
 
                    list5 = p5.findall(str(substring))
                    if list5 ==[]:
                        p4 = re.compile(r'\d+.\d+.\d+.\d+\s+')
                        list4 = p4.findall(str(substring))
                        T = listToString(list4[-1])
                        print("This is list 4",list4,"Found the Text on page",i+1)
                        print("this is content 4: ",T)
####################################level 3#####################################################################################
                    pa3 = re.compile(r'\d+.\d+.\d+')
                    print("THIS IS OF A three DIGITS",pa3.findall(str(list4[-1])))
                    third = pa3.findall(str(list4[-1]))
                    TTT = listToString(third)
                    print("this is content 3: ",TTT)
                    pat = re.compile("\s"+TTT+"\s+\D+\s+")
                    for i in range(0, 5):
                        page = doc[i]
                        text = page.get_text("text")
                        found = re.finditer(pat, text)
                        if pat.search(text):
                            print("Found the Text on page",i+1)
                            list = pat.findall(str(text))
                            print("LEVEL 3:",list)
##########################################################level 2###############################################################
                    pa2 = re.compile(r'\d+.\d+')
                    print("THIS IS OF A two DIGITS",pa2.findall(str(list4[-1])))
                    second = pa2.findall(str(list4[-1]))
                    TT = listToString(second[0])
                    print("this is content 2: ",TT)
                    pat = re.compile("\s"+TT+"\s+\D+\s+")
                    for i in range(0, 5):
                        page = doc[i]
                        text = page.get_text("text")
                        found = re.finditer(pat, text)
                        if pat.search(text):
                            print("Found the Text on page",i+1)
                            list = pat.findall(str(text))
                            print("LEVEL 2",list)

################################################level 1 ########################################################################

                    pa1 = re.compile(r'\d')
                    print("THIS IS OF A one DIGITS",pa1.findall(str(list4[-1])))
                    third = pa1.findall(str(list4[-1]))
                    T = listToString(third[0])
                    print("this is content 1: ",T)
                    pat = re.compile("\s"+T+"\s+\D+\s+")
                    for i in range(0, 5):
                        page = doc[i]
                        text = page.get_text("text")
                        #print(text)
                        found = re.finditer(pat, text)
                        #print(found)
                        if pat.search(text):
                            print("Found the Text on page",i+1)
                            list = pat.findall(str(text))
                            print("LEVEL 1:",list)
# Out:
# Enter_the_text_to_Search_here: Typically implemented with a monostable circuit
# Found the Text on page 104 from the file : ISO_26262-11_Dez.-2018.pdf
# This is list 4 ['5.2.4.6 \n', '5.2.4.7 \n'] Found the Text on page 104
# this is content 4:  5.2.4.7
#
# THIS IS OF A three DIGITS ['5.2.4']
# this is content 3:  5.2.4
# Found the Text on page 4
# LEVEL 3: ['\n5.2.4 \nExamples of safety mechanisms ']
# THIS IS OF A two DIGITS ['5.2', '4.7']
# this is content 2:  5.2
# Found the Text on page 4
# LEVEL 2 ['\n5.2 \nAnalogue/mixed signal components ']
# THIS IS OF A one DIGITS ['5', '2', '4', '7']
# this is content 1:  5
# Found the Text on page 3
# LEVEL 1: ['\n5\t\nSpecific\tsemiconductor\ttechnologies\tand\tuse\tcases ']

# %% [markdown]
# ### Summed up function

# %% [markdown]
# ##### main functionality

# %%
# import required module
import os
import re
import PyPDF2 
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here: "))
for filename in os.listdir(directory):
    if not filename.startswith('~$') and filename.endswith('.pdf'):
        f = os.path.join(directory, filename)
        doc = fitz.open(f)
        page_count = len(doc)
        #print(page_count)
        for i in range(0, page_count):
            page = doc[i]
            text = page.get_text("text")
            found = re.finditer(pattern, text)
            #print(type(text))
            #print(text)
            if pattern.search(text):
                print("Found the Text on page",i+1, "from the file :", filename)
                #print(text)
                for item in found:
                    s = item.start()
                    e = item.end()
                    substring = text[s-400:e]
                    #print('THIS',substring)
                    #print(substring)
                    p5 = re.compile(r'\d+.\d+.\d+.\d+.\d+\s+')
                    list5 = p5.findall(str(substring))
                    print("stage 5",list5)
                    if list5 ==[]:
                        p4 = re.compile(r'\d+.\d+.\d+.\d+\s+')
                        list5 = p4.findall(str(substring))
                        print(list5)
                        
                        if list5 ==[]:
                            p3 = re.compile(r'\d+.\d+.\d+\s+')
                            list5 = p3.findall(str(substring))
                            if list5 ==[]:
                                p2 = re.compile(r'\d+.\d+\s+')
                                list5 = p2.findall(str(substring))
                                Two_list(list5,page_count)
                            else:
                                Three_list (list5,page_count)
                                
                        else:
                            fourth_list (list5,page_count)
                    else:
                        Fifth_list (list5,page_count)
#############################################level 4 ###########################################################################
# Out:
# Enter_the_text_to_Search_here: safety-related content of the service plan
# Found the Text on page 18 from the file : ISO_26262-7.pdf
# stage 5 []
# []
# THIS IS OF A two DIGITS ['7.3']
# this is content 2:  7.3
# Found the Text on page 3
# LEVEL 2 ['\n7.3 \nInputs to this clause ']
# this is T :
# 7

# %%
def Fifth_list (list5,page_count):
    pa4 = re.compile(r'\d+.\d+.\d+.\d+')
    print("THIS IS OF A four DIGITS",pa4.findall(str(list5[-1])))
    fourth = pa4.findall(str(list5[-1]))
    TTTT = listToString(fourth)
    print("this is content 4: ",TTTT)
    pat = re.compile("\s"+TTTT+"\s+\D+\s+")
    for i in range(0, page_count):
        page = doc[i]
        #print(i)
        text = page.get_text("text")
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list4 = pat.findall(str(text))
            print("LEVEL 4:",list4)
            
####################################level 3#####################################################################################
    pa3 = re.compile(r'\d+.\d+.\d+')
    print("THIS IS OF A three DIGITS",pa3.findall(str(list5[-1])))
    third = pa3.findall(str(list5[-1]))
    TTT = listToString(third)
    print("this is content 3: ",TTT)
    pat = re.compile("\s"+TTT+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list3 = pat.findall(str(text))
            print("LEVEL 3:",list3)
##########################################################level 2###############################################################
    pa2 = re.compile(r'\d+.\d+')
    print("THIS IS OF A two DIGITS",pa2.findall(str(list5[-1])))
    second = pa2.findall(str(list5[-1]))
    TT = listToString(second[0])
    print("this is content 2: ",TT)
    pat = re.compile("\s"+TT+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list2 = pat.findall(str(text))
            print("LEVEL 2",list2)

################################################level 1 ########################################################################

    pa1 = re.compile(r'\d')
    print("THIS IS OF A one DIGITS",pa1.findall(str(list5[-1])))
    third = pa1.findall(str(list5[-1]))
    T = listToString(third[0])
    print("this is content 1: ",T)
    pat = re.compile("\s"+T+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        #print(text)
        found = re.finditer(pat, text)
        #print(found)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list1 = pat.findall(str(text))
            print("LEVEL 1:",list1)
            return list1

# %%
def fourth_list(list5,page_count):
    pa3 = re.compile(r'\d+.\d+.\d+')
    print("THIS IS OF A three DIGITS",pa3.findall(str(list5[-1])))
    third = pa3.findall(str(list5[-1]))
    TTT = listToString(third[0])
    print("this is content 3: ",TTT)
    pat = re.compile("\s"+TTT+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list3 = pat.findall(str(text))
            print("LEVEL 3:",list3)
##########################################################level 2###############################################################
##########################################################level 2###############################################################
    pa2 = re.compile(r'\d+.\d+')
    print("THIS IS OF A two DIGITS",pa2.findall(str(list5[-1])))
    second = pa2.findall(str(list5[-1]))
    TT = listToString(second[0])
    print(TT)
    print("this is content 2: ",TT)
    pat = re.compile("\s"+TT+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list2 = pat.findall(str(text))
            print("LEVEL 2",list2)

################################################level 1 ########################################################################
    pa1 = re.compile(r'\d')
    #T = listToString(list2)
    T = TT.rpartition('.')[0]
    print("this is T :",T)
    pat = re.compile("\s"+T+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        
        text = page.get_text("text")
        #print(text)
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list = pat.findall(str(text))
            print("LEVEL 1:",list)

# %%
def Three_list(list5,page_count):
##########################################################level 2###############################################################
    pa2 = re.compile(r'\d+.\d+')
    print("THIS IS OF A two DIGITS",pa2.findall(str(list5[-1])))
    second = pa2.findall(str(list5[-1]))
    TT = listToString(second[0])
    print("this is content 2: ",TT)
    pat = re.compile("\s"+TT+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list2 = pat.findall(str(text))
            print("LEVEL 2",list2)

################################################level 1 ########################################################################
    pa1 = re.compile(r'\d')
    T = listToString(list2)
    T = T.rpartition('.')[0]
    print("this is T :",T)
    pat = re.compile("\s"+T+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        #print(text)
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list1 = pat.findall(str(text))
            print("LEVEL 1:",list1)
            return list1
# Out:
#   Input In [71]
#     def Three_list(list5,5):
#                          ^
# SyntaxError: invalid syntax

# %%
def Two_list(list5,page_count):
##############################################level 1 ##########################################################################
    pa1 = re.compile(r'\d')
    T = listToString(list2)
    T = T.rpartition('.')[0]
    pat = re.compile("\s"+T+"\s+\D+\s+")
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        #print(text)
        found = re.finditer(pat, text)
        if pat.search(text):
            print("Found the Text on page",i+1)
            list = pat.findall(str(text))
            print("LEVEL 1:",list)

# %% [markdown]
# ### search with lemmatization

# %%
# Perform standard imports, reset nlp
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# import required module
import os
import re
import PyPDF2 
import fitz

# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
filename = 'ISO_26262-6.pdf'

# iterate over files in
# that directory
Input = input("Enter_the_text_to_Search_here")
pattern = re.compile(Input)
doc1 = nlp(Input)
my_list1= []
for token in doc1:
    print(token.text, '\t', token.pos_, '\t', token.lemma, '\t', token.lemma_)
    my_list1.append(token.lemma_+'')
    final = (' '.join(map(str, my_list1)))
    Final = re.compile(final)
    print("this is final",final)
    doc3 = nlp(final)
    for chunk in doc3.noun_chunks:
        print("those are the other chunks lemmatisation:",chunk.text)
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
   
    #print(page_count)
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        #print(type(text))
        #print(text)
        if pattern.search(text) or Final.search(text):
            print("Found the Text on page",i+1, "from the file :", filename)
            doc3 = nlp(text)
            #print([(X.text, X.label_) for X in doc3.ents])
            for X in doc3.ents:
                if  X.label_ == "ORG":
                    print(X)
                    #sentences = [x for x in X.sents]
                    #displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# Enter_the_text_to_Search_hereTesting of the embedded software
# Testing 	 NOUN 	 2754665471364627735 	 testing
# this is final testing
# those are the other chunks lemmatisation: testing
# of 	 ADP 	 886050111519832510 	 of
# this is final testing of
# those are the other chunks lemmatisation: testing
# the 	 DET 	 7425985699627899538 	 the
# this is final testing of the
# those are the other chunks lemmatisation: testing
# those are the other chunks lemmatisation: the
# embedded 	 VERB 	 11937460623250955776 	 embed
# this is final testing of the embed
# those are the other chunks lemmatisation: testing
# those are the other chunks lemmatisation: the embed
# software 	 NOUN 	 8212201967714533330 	 software
# this is final testing of the embed software
# those are the other chunks lemmatisation: testing
# those are the other chunks lemmatisation: the embed software
# Found the Text on page 4 from the file : ISO_26262-6.pdf
# ISO 26262-6:2018(E
# .........................................................................................................................................
# Annex C
# B55EB1B3C7662F79D1B59483A53B9F2F82C98BEEB7939F8F78D1289AD055D58964FE4F0187EF0BB89DAE48F36347E38EAE72D5AF45A12F189F2F08A074973B886664EEE2157E49FD482F010710BD2377F1B96937B3A6BA9EDD
# Normen-Download-Beuth-Lisa
# Found the Text on page 36 from the file : ISO_26262-6.pdf
# ISO 26262-6:2018(E
# C.5.4
# ISO 26262-4:2018
# ISO 26262-4:2018
# ISO 26262-4:2018
# B55EB1B3C7662F79D1B59483A53B9F2F82C98BEEB7939F8F78D1289AD055D58964FE4F0187EF0BB89DAE48F36347E38EAE72D5AF45A12F189F2F08A074973B886664EEE2157E49FD482F010710BD2377F1B96937B3A6BA9EDD
# Normen-Download-Beuth-Lisa

# %% [markdown]
# # Sending an email

# %%
import win32com.client as win32
outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)
mail.To = 'Samar.Jberi.extern@draexlmaier.com'
mail.Subject = 'Files Update'
mail.Body = 'Message body'
mail.HTMLBody = '<h2>could yoou please add the file iso26269-11 to the Drive , Thank you</h2>' #this field is optional

# To attach a file to the email (optional):
#attachment  = "Path to the attachment"
#mail.Attachments.Add(attachment)

mail.Send()
