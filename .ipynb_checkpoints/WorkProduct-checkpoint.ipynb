# %%
import spacy
nlp = spacy.load('en_core_web_sm')
import fitz

# %%
# Import the Matcher library
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
pattern1 = [{'LOWER': 'Requirements and recommendations'}]

matcher.add('Requirements', [pattern1])
doc = nlp(u'guidelines for the application of tools (from an external source). 5.4 Requirements and recommendations 5.4.1 When developing the software of an item, software development processes and software development environments shall be used which:')
found_matches = matcher(doc)
print(found_matches)
# Out:
# []

# %%
# import required module
import os
import re
import PyPDF2 
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
filename = 'ISO_26262-6.pdf'

# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        #print(type(text))
        #print(text)
        if pattern.search(text):
            print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-600:e]
                #print(substring)
                pattern1 = re.compile("Requirements and recommendations")
                found1 = re.finditer(pattern1, substring)
                if pattern.search(substring):
                    print("element found")
                    for item in found1:
                        s = item.start()
                        e = item.end()
                        substring1 = substring[s-5:e]
                        print(substring1)
# Out:
# Enter_the_text_to_Search_hereThe software safety requirements are either derived directly
# Found the Text on page 16 from the file : ISO_26262-6.pdf
# element found
#
# 6.4 Requirements and recommendations

# %%
# import required module
import os
import re
import PyPDF2 
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
filename = 'ISO_26262-6.pdf'

# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        #print(type(text))
        #print(text)
        if pattern.search(text):
            print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-600:e]
                #print(substring)
                
                pattern1 = re.compile("Requirements and recommendations")
                found1 = re.finditer(pattern1, substring)
                if pattern.search(substring):
                    print("element found")
                    for item in found1:
                        s = item.start()
                        e = item.end()
                        substring1 = substring[s-5:e]
                        print(substring1)
                        p = re.compile(r'\d+.\d+\s+')
                        list = p.findall(str(substring1))
                        #print("this is a list :",p.findall(str(substring1)))
                        for i in list:
                            pat = re.compile(r'\d+')
                            second = pat.findall(str(list))
                            T = listToString(second[:1])
                            #print("this is T ",T)
                            pat = re.compile(T+".\d+\s"+"Work products")
                            for i in range(0, page_count):
                                page = doc[i]
                                text = page.get_text("text")
                                list1 = pat.findall(str(text))
                                res = []
                                for i in list1:
                                    if i:
                                        res.append(i)
                                        #print(res)
                                        resultFound = listToString(res)
                                        #print(resultFound)
                                        patf = re.compile(resultFound)
                                        for i in range(0, page_count):
                                            page = doc[i]
                                            text = page.get_text("text")
                                            found3 = re.finditer(patf, text)
                                            for item in found3:
                                                s = item.start()
                                                e = item.end()
                                                substring3 = text[s:e+850]
                                                print("work Product related Content Found the Text on page",i+1,"\n",substring3)
                                        
                                        #found3 = re.finditer(patf, text)
                                        #for i in range(0, page_count):
                                            #page = doc[i]
                                            #text = page.get_text("text")
                                            #for item in found3:
                                                #print(item)
                                                #s = item.start()
                                                #e = item.end()
                                                #substring3 = text[s:e+100]
                                                #print(substring3)
                               # if pat.search(text):
                                    #print("element found")
                                    #print(pat.findall(str(text)))
# Out:
# Enter_the_text_to_Search_herePerforming verification at the model level can substitute
# Found the Text on page 28 from the file : ISO_26262-6.pdf
# element found

# %%
# Function to convert  
def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    
    # return string  
    return str1

# %% [markdown]
# # Going from work product to requirements

# %%
# import required module
import os
import re
import PyPDF2 
import fitz
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
filename = 'ISO_26262-4.pdf'

# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    for i in range(0, 5):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        #print(type(text))
        #print(text)
        if pattern.search(text):
            print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                #print(substring)
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                #print(list[-1])
                T = listToString(list[-1])
                TT = (int(T))
                TT= TT+1
                TT = (str(TT))
                print(type(TT))
                pat = re.compile(T+".\d+\s"+"Work products")
                for i in range(0, page_count):
                    page = doc[i]
                    text = page.get_text("text")
                    list1 = pat.findall(str(text))
                    found3 = re.finditer(pat, text)
                    #print(list1)
                    res = []
                    for i in list1:
                        if i:
                            res.append(i)
                            #print(res)
                            resultFound = listToString(res)
                            print("Work Products:", resultFound)
                            PR = re.compile(r'\d+.\d+')
                            
                            list4 = PR.findall(str(resultFound))
                            
                            
                            
                            
                            for item in found3:
                                s = item.start()
                                e = item.end()
                                substring3 = text[s:e+500]
                                print(substring3.split(TT)[0])
                                p = re.compile(r'\d+.\d+.\d+')
                                list2 = p.findall(str(substring3))
                                print(list2)
                                TTT = listToString1(list2)
                                print("this is the list of digits:",TTT)
                                wp = listToString(list4)
                                Num = wp
                                print(Num)
                                Numbers = re.findall(Num+".\d", TTT)
                                print(type(Numbers))
                                
                                TTTT = listToString1(Numbers)
                                print(TTTT)
                                for x in Numbers:
                                    print(x)
                                    list2.remove(x)
                                print(list2)
                                for x in list2:
                                    patternWP = re.compile(x+"\s+.*\.")
                                    for i in range(0, 5):
                                        page = doc[i]
                                        text = page.get_text("text")
                                        list6 = patternWP.findall(str(text))
                                        #print(list6)
                                        res1 = []
                                        for i in list6:
                                            if i:
                                                res1.append(i)
                                                #print(res1)
                                                resultFound = listToString(res1)
                                                print(resultFound)
# Out:
# Enter_the_text_to_Search_hereSystem and item integration and testing
# Found the Text on page 3 from the file : ISO_26262-4.pdf
# <class 'str'>
# Work Products: 7.5 Work products
# 7.5 Work products
# 7.5.1
# Integration and test strategy resulting from requirements in 7.4.1.
# 7.5.2
# Integration and test report resulting from requirements in 7.4.2, 7.4.3 and 7.4.4.
#
# ['7.5.1', '7.4.1', '7.5.2', '7.4.2', '7.4.3', '7.4.4']
# this is the list of digits: 7.5.1 7.4.1 7.5.2 7.4.2 7.4.3 7.4.4
# 7.5
# <class 'list'>
# 7.5.1 7.5.2
# 7.5.1
# 7.5.2
# ['7.4.1', '7.4.2', '7.4.3', '7.4.4']
# 7.4.1
# Specification of integration and test strategy ......................................................................................
# 7.4.2
# Hardware-software integration and testing ..........................................................................................
# 7.4.3
# System integration and testing .........................................................................................................................
# 7.4.4
# Vehicle integration and testing .........................................................................................................................

# %%
# Function to convert  
def listToString1(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele+" "  
    
    # return string  
    return str1
