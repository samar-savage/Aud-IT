# %%
pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in c:\users\xjs09914403\anaconda3\lib\site-packages (1.19.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tabula-py
# Out:
# Requirement already satisfied: tabula-py in c:\users\xjs09914403\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: distro in c:\users\xjs09914403\anaconda3\lib\site-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\xjs09914403\anaconda3\lib\site-packages (from tabula-py) (1.4.2)
# Requirement already satisfied: numpy in c:\users\xjs09914403\anaconda3\lib\site-packages (from tabula-py) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\xjs09914403\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\xjs09914403\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\xjs09914403\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula
import fitz
import re

# %%
tables = tabula.read_pdf("C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-3.pdf" ,pages=16, multiple_tables=True)
print(tables[0])
# Out:
#     Unnamed: 0   Unnamed: 1                   Unnamed: 2  \
# 0          NaN           S0                           S1
# 1  Description  No injuries  Light and moderate injuries
#
#                                                Class  \
# 0                                                 S2
# 1  Severe and life-threatening (survival probable...
#
#                                           Unnamed: 3
# 0                                                 S3
# 1  Life-threatening injuries (survival uncertain)...

# %%
# import required module
import os
import re
import PyPDF2 
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
for filename in os.listdir(directory):
    if not filename.startswith('~$') and filename.endswith('.pdf'):
        f = os.path.join(directory, filename)
        doc = fitz.open(f)
        page_count = len(doc)
        #print(page_count)
        for i in range(0, page_count):
            page = doc[i]
            text = page.get_text("text")
            #print(text)
            if pattern.search(text):
                
                print("Found the Text on page",i+1, "from the file :", filename)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 9>()
#       6 directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
#       7 # iterate over files in
#       8 # that directory
# ----> 9 pattern = re.compile(input("Enter_the_text_to_Search_here"))
#      10 for filename in os.listdir(directory):
#      11     if not filename.startswith('~$') and filename.endswith('.pdf'):
#
# File ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import tabula
# readinf the PDF file that contain Table Data
# you can find find the pdf file with complete code in below
# read_pdf will save the pdf table into Pandas 
f = "C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-3.pdf"
doc = fitz.open(f)
page_count = len(doc)
print(page_count)

for i in range(0, (len(f))):
    df = tabula.read_pdf(f, pages= i,multiple_tables=True)
# in order to print first 5 lines of Table
    print(df,"PAGE NUMBER",i+1)
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 40
# [] PAGE NUMBER 1
# [] PAGE NUMBER 2
# [] PAGE NUMBER 3
# [] PAGE NUMBER 4
# [] PAGE NUMBER 5
# [] PAGE NUMBER 6
# [] PAGE NUMBER 7
# [] PAGE NUMBER 8
# [] PAGE NUMBER 9
# [] PAGE NUMBER 10
# [] PAGE NUMBER 11
# [] PAGE NUMBER 12
# [] PAGE NUMBER 13
# [] PAGE NUMBER 14
# [] PAGE NUMBER 15
# [] PAGE NUMBER 16
# [    Unnamed: 0   Unnamed: 1                   Unnamed: 2  \
# 0          NaN           S0                           S1
# 1  Description  No injuries  Light and moderate injuries
#
#                                                Class  \
# 0                                                 S2
# 1  Severe and life-threatening (survival probable...
#
#                                           Unnamed: 3
# 0                                                 S3
# 1  Life-threatening injuries (survival uncertain)...  ,     Unnamed: 0  Unnamed: 1            Unnamed: 2            Class  \
# 0          NaN          E0                    E1               E2
# 1  Description  Incredible  Very low probability  Low probability
#
#            Unnamed: 3        Unnamed: 4
# 0                  E3                E4
# 1  Medium probability  High probability  ] PAGE NUMBER 17
# [    Unnamed: 0               Unnamed: 1           Unnamed: 2  \
# 0          NaN                       C0                   C1
# 1  Description  Controllable in general  Simply controllable
#
#                    Class                              Unnamed: 3
# 0                     C2                                      C3
# 1  Normally controllable  Difficult to control or uncontrollable  ] PAGE NUMBER 18
# [   Unnamed: 0      Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 0         NaN  Severity class  Exposure class        NaN
# 1         NaN             NaN             NaN         C1
# 2         NaN             NaN              E1         QM
# 3         NaN             NaN              E2         QM
# 4         NaN              S1             NaN        NaN
# 5         NaN             NaN              E3         QM
# 6         NaN             NaN              E4         QM
# 7         NaN             NaN              E1         QM
# 8         NaN             NaN              E2         QM
# 9         NaN              S2             NaN        NaN
# 10        NaN             NaN              E3         QM
# 11        NaN             NaN              E4          A
# 12        NaN             NaN              E1         QM
# 13        NaN             NaN              E2         QM
# 14        NaN              S3             NaN        NaN
# 15        NaN             NaN              E3          A
# 16        NaN             NaN              E4          B
# 17          a   See 6.4.3.11.             NaN        NaN
#
#    Controllability class Unnamed: 4
# 0                    NaN        NaN
# 1                     C2         C3
# 2                     QM         QM
# 3                     QM         QM
# 4                    NaN        NaN
# 5                     QM          A
# 6                      A          B
# 7                     QM         QM
# 8                     QM          A
# 9                    NaN        NaN
# 10                     A          B
# 11                     B          C
# 12                    QM         Aa
# 13                     A          B
# 14                   NaN        NaN
# 15                     B          C
# 16                     C          D
# 17                   NaN        NaN  ] PAGE NUMBER 19
# [] PAGE NUMBER 20
# [] PAGE NUMBER 21
# [] PAGE NUMBER 22
# [] PAGE NUMBER 23
# [] PAGE NUMBER 24
# [] PAGE NUMBER 25
# [] PAGE NUMBER 26
# [                     Unnamed: 0  Clause  \
# 0                             5     NaN
# 1               Item definition     NaN
# 2                           NaN     NaN
# 3                           NaN     NaN
# 4                           NaN     NaN
# 5                           NaN     NaN
# 6                           NaN     NaN
# 7                           NaN     NaN
# 8                             6     NaN
# 9                  Hazard anal-     NaN
# 10                ysis and risk     NaN
# 11                   assessment     NaN
# 12                          NaN     NaN
# 13                          NaN     NaN
# 14                          NaN     NaN
# 15                          NaN     NaN
# 16                            7     NaN
# 17  Functional safe- ty concept     NaN
# 18                          NaN     NaN
# 19                          NaN     NaN
# 20                          NaN     NaN
# 21                          NaN     NaN
# 22                          NaN     NaN
# 23                          NaN     NaN
# 24                          NaN     NaN
# 25                          NaN     NaN
# 26                          NaN     NaN
# 27                          NaN     NaN
# 28                          NaN     NaN
# 29                          NaN     NaN
# 30                          NaN     NaN
# 31                          NaN     NaN
# 32                          NaN     NaN
# 33                          NaN     NaN
#
#                                            Objectives  \
# 0                  The objectives of this Clause are:
# 1             a) to define and describe the item, its
# 2        functionality, dependencies on, and interac-
# 3          tion with, the driver, the environment and
# 4               other items at the vehicle level; and
# 5                    b) to support an adequate under-
# 6      standing of the item so that the activities in
# 7                 subsequent phases can be performed.
# 8                  The objectives of this Clause are:
# 9                                                 NaN
# 10            a) to identify and to classify the haz-
# 11  ardous events caused by malfunctioning behavio...
# 12              b) to formulate the safety goals with
# 13           their corresponding ASILs related to the
# 14          prevention or mitigation of the hazardous
# 15       events, in order to avoid unreasonable risk.
# 16                 The objectives of this Clause are:
# 17  a) graded functional behaviour of the item in ...
# 18                  accordance with its safety goals;
# 19              b) to specify the constraints regard-
# 20         ing suitable and timely detection and con-
# 21     trol of relevant faults in accordance with its
# 22                                      safety goals;
# 23            c) to specify the item level strategies
# 24          or measures to achieve the required fault
# 25       tolerance or adequately mitigate the effects
# 26      of relevant faults by the item itself, by the
# 27                    driver or by external measures;
# 28               d) to allocate the functional safety
# 29           requirements to the system architectural
# 30               design, or to external measures; and
# 31                 e) to verify the functional safety
# 32          concept and specify the safety validation
# 33                                          criteria.
#
#                   Prerequisites  \
# 0                          None
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8               Item definition
# 9                           NaN
# 10                  (see 5.5.1)
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16              Item definition
# 17  (see 5.5.1) Hazard analysis
# 18          and risk assessment
# 19           report (see 6.5.1)
# 20             System architec-
# 21           tural design (from
# 22             external source)
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
# 31                          NaN
# 32                          NaN
# 33                          NaN
#
#                                         Work products
# 0                               5.5.1 Item definition
# 1                             resulting from require-
# 2                                       ments in 5.4.
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                           6.5.1 Hazard analysis and
# 9                                                 NaN
# 10                         risk assessment report re-
# 11          sulting from requirements 6.4.1 to 6.4.5.
# 12                          6.5.2 Verification report
# 13                         of the hazard analysis and
# 14                          risk assessment resulting
# 15                            from requirement 6.4.6.
# 16                            7.5.1 Functional safety
# 17  concept resulting from requirements 7.4.1 to 7...
# 18                          7.5.2 Verification report
# 19                           of the functional safety
# 20                             concept resulting from
# 21                             requirements in 7.4.4.
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN  ] PAGE NUMBER 27
# [] PAGE NUMBER 28
# [] PAGE NUMBER 29
# [                                           Unnamed: 0  \
# 0                                                 NaN
# 1                                         Description
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                           Reference
# 6                                          for single
# 7                                  injuries (from AIS
# 8                                              scale)
# 9                                            Examples
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  NOTEThe informative examples in Table B.1 can ...
# 32                                        case basis.
#
#                     Unnamed: 1 Unnamed: 2  \
# 0                          NaN         S0
# 1                  No injuries        NaN
# 2                          NaN        NaN
# 3                          NaN        NaN
# 4                          NaN        NaN
# 5     AIS 0 and less than 10 %        NaN
# 6   probability of AIS 1-6; or        NaN
# 7        damage that cannot be        NaN
# 8    classified safety-related        NaN
# 9        — Bumps with roadside        NaN
# 10              infrastructure        NaN
# 11                         NaN        NaN
# 12     — Pushing over roadside        NaN
# 13           post, fence, etc.        NaN
# 14                         NaN        NaN
# 15      — Light grazing damage        NaN
# 16          — Damage entering/        NaN
# 17       exiting parking space        NaN
# 18          — Leaving the road        NaN
# 19        without collision or        NaN
# 20                    rollover        NaN
# 21                         NaN        NaN
# 22                         NaN        NaN
# 23                         NaN        NaN
# 24                         NaN        NaN
# 25                         NaN        NaN
# 26                         NaN        NaN
# 27                         NaN        NaN
# 28                         NaN        NaN
# 29                         NaN        NaN
# 30                         NaN        NaN
# 31                         NaN        NaN
# 32                         NaN        NaN
#
#                       Class of severity (see Table 1)
# 0                                            S1 S2 S3
# 1   Light and moderate Severe and Life-threatening...
# 2     injuries life-threatening ries (survival uncer-
# 3            injuries (survival tain), fatal injuries
# 4                                           probable)
# 5   More than 10 % prob- More than 10 % More than ...
# 6   ability of AIS 1-6 (and probability of AIS 3-6...
# 7                          not S2 or S3) (and not S3)
# 8                                                 NaN
# 9           — Side impact — Side impact — Side impact
# 10          with a narrow with a narrow with a narrow
# 11           stationary object, stationary stationary
# 12           e.g. passenger object, e.g. object, e.g.
# 13      car crashing into passenger car passenger car
# 14  a tree (impact to crashing into a crashing into a
# 15    passenger cell) tree (impact to tree (impact to
# 16      with very low passenger cell) passenger cell)
# 17             speed with low speed with medium speed
# 18                          — Rear/front — Rear/front
# 19              collision with collision — Rear/front
# 20  another passenger car with very low with anoth...
# 21                   speed with low speed with medium
# 22                                              speed
# 23                    — Front collision — Pedestrian/
# 24  (e.g. rear-ending bicycle accident — Front col...
# 25  another vehicle, with low speed (e.g. rear-ending
# 26                     semi-trailer, another vehicle,
# 27                  etc.) without semi-trailer, etc.)
# 28                           passenger with passenger
# 29                            compartment compartment
# 30                            deformation deformation
# 31                                                NaN
# 32                                                NaN  ] PAGE NUMBER 30
# [        Unnamed: 0  \
# 0              NaN
# 1      Description
# 2         Duration
# 3    (% of average
# 4  operating time)
# 5     Examples for
# 6      road layout
# 7              NaN
# 8              NaN
# 9              NaN
#
#   Class of probability of exposure in operational situations (see Table 2)
# 0                                        E1 E2 E3 E4
# 1  Very low probability Low probability Medium pr...
# 2  Not specified <1 % of average oper- 1 % to 10 ...
# 3       ating time age operating time operating time
# 4                                                NaN
# 5          — Country road — One-way street — Highway
# 6                         intersection (city street)
# 7                                   — — Country road
# 8                                     — Highway exit
# 9                                               ramp                        ] PAGE NUMBER 31
# [            Unnamed: 0 Unnamed: 1  \
# 0                  NaN        NaN
# 1         Examples for        NaN
# 2         road surface        NaN
# 3                  NaN        NaN
# 4                  NaN        NaN
# 5                  NaN        NaN
# 6         Examples for          —
# 7   vehicle stationary        NaN
# 8                state        NaN
# 9                  NaN          —
# 10                 NaN        NaN
# 11                 NaN        NaN
# 12        Examples for          —
# 13           manoeuvre        NaN
# 14                 NaN        NaN
# 15                 NaN        NaN
# 16                 NaN        NaN
# 17                 NaN        NaN
# 18                 NaN        NaN
# 19                 NaN        NaN
# 20                 NaN        NaN
#
#    Class of probability of exposure in operational situations (see Table 2)
# 0                                         E1 E2 E3 E4
# 1                        — Snow and ice on — Wet road
# 2                                                road
# 3                                                 — —
# 4                                   — Slippery leaves
# 5                                             on road
# 6   Vehicle during — Trailer attached — Vehicle on...
# 7                              jump start (hill hold)
# 8                                         — Roof rack
# 9                         In repair garage attached —
# 10                                    — Vehicle being
# 11                                          refuelled
# 12  Driving downhill — Driving in — Heavy traffic ...
# 13              with engine off reverse (stop and go)
# 14                     (mountain pass) — Decelerating
# 15                                       — Overtaking
# 16                              — Stopping at traffic
# 17                — Parking (with light (city street)
# 18                                  trailer attached)
# 19                                      — Lane change
# 20                                          (highway)                        ,             Unnamed: 0  \
# 0                  NaN
# 1          Description
# 2         Frequency of
# 3            situation
# 4                  NaN
# 5                  NaN
# 6         Examples for
# 7          road layout
# 8                  NaN
# 9         Examples for
# 10        road surface
# 11        Examples for
# 12  vehicle stationary
# 13               state
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18        Examples for
# 19           manoeuvre
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
#
#    Class of probability of exposure in operational situations (see Table 2)
# 0                                         E1 E2 E3 E4
# 1   Very low probability Low probability Medium pr...
# 2   Occurs less often Occurs a few times Occurs on...
# 3   than once a year for a year for the great or m...
# 4   the great majority of majority of drivers aver...
# 5                                             drivers
# 6                                     — Mountain pass
# 7                                — with unsecured — —
# 8                                         steep slope
# 9                        — Snow and ice on — Wet road
# 10                                           — road —
# 11             — Stopped, — Roof rack — Vehicle being
# 12                requiring engine attached refuelled
# 13                                        restart (at
# 14            railway crossing) — Vehicle on a hill —
# 15                                        (hill hold)
# 16                                    — Vehicle being
# 17                                              towed
# 18                  — Evasive — Overtaking — Shifting
# 19                            manoeuvre, transmission
# 20                               deviating from gears
# 21                                       desired path
# 22                                 — Executing a turn
# 23                                       — (steering)
# 24                                 — Using indicators
# 25                                       — Driving in
# 26                                            reverse                        ] PAGE NUMBER 32
# [                                           Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                           Examples
# 14                                                for
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  NOTEThe informative examples in Table B.2 can ...
# 23  situations occurring in both, Table B.2 and Ta...
#
#                                     Unnamed: 1  \
# 0                                          NaN
# 1                                          NaN
# 2                                  Description
# 3                                          NaN
# 4                                     Duration
# 5                (% of average operating time)
# 6                                          NaN
# 7                           driving in reverse
# 8         overtaking another truck or bus with
# 9            small speed difference (with lane
# 10                    change to oncoming lane)
# 11               driving with trailer attached
# 12        semi-trailer tractor without trailer
# 13                   attached (on public road)
# 14                                         NaN
# 15    driving on construction site (vehicle is
# 16  driving directly on construction site, not
# 17      only for delivering goods to construc-
# 18                                  tion site)
# 19                                 steep slope
# 20                      standing at a bus stop
# 21          entering/driving off from bus stop
# 22                                         NaN
# 23                                         NaN
#
#       Class of probability of exposure in operational
# 0                            situations (see Table 2)
# 1                                         E1 E2 E3 E4
# 2   Very low probability Low proba- bility Medium ...
# 3                        <1 % of 1 % to 10 % >10 % of
# 4                                                 NaN
# 5   Not specifiedaverage operating of average oper...
# 6                                      time time time
# 7                           — LH, CB, CO, IB DI, VO —
# 8                                                 NaN
# 9                                   LH, DI, VO, — — —
# 10                                             CO, IB
# 11                              — — DI, CO, IB LH, VO
# 12                                                NaN
# 13                                   — LH, DI, VO — —
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                         LH DI — VO
# 18                                                NaN
# 19                             LH, CB DI, CO, IB VO —
# 20                                      — — CO CB, IB
# 21                                      — CO CB, IB —
# 22                                                NaN
# 23                                                NaN  ] PAGE NUMBER 33
# [                                           Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                           Examples
# 14                                                for
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  NOTEThe informative examples in Table B.3 can ...
# 23  situations occurring in both Table B.3 and Tab...
#
#                                     Unnamed: 1  \
# 0                                          NaN
# 1                                          NaN
# 2                                  Description
# 3                                          NaN
# 4                                          NaN
# 5                       Frequency of situation
# 6                                          NaN
# 7                                          NaN
# 8                           driving in reverse
# 9         overtaking another truck or bus with
# 10           small speed difference (with lane
# 11                    change to oncoming lane)
# 12               driving with trailer attached
# 13        semi-trailer tractor without trailer
# 14                   attached (on public road)
# 15    driving on construction site (vehicle is
# 16  driving directly on construction site, not
# 17      only for delivering goods to construc-
# 18                                  tion site)
# 19                                 steep slope
# 20      standing at/entering/driving off a bus
# 21                                        stop
# 22                                         NaN
# 23                                         NaN
#
#       Class of probability of exposure in operational
# 0                            situations (see Table 2)
# 1                                         E1 E2 E3 E4
# 2   Very low probability Low proba- bility Medium ...
# 3                                         Occurs less
# 4   often than Occurs a few times a year Occurs on...
# 5   once a year for the great for the great more o...
# 6   majority of majority of for an aver-every driv...
# 7                          drivers drivers age driver
# 8                           — — CB LH, DI, VO, CO, IB
# 9                                                 NaN
# 10                                  — — LH, DI, VO, —
# 11                                             CO, IB
# 12                              — — DI, CO, IB LH, VO
# 13                                                NaN
# 14                                      — DI, VO LH —
# 15                                                NaN
# 16                                                NaN
# 17                                         LH DI — VO
# 18                                                NaN
# 19                             LH, CB DI, CO, IB — VO
# 20                                                NaN
# 21                                   — — — CB, CO, IB
# 22                                                NaN
# 23                                                NaN  ] PAGE NUMBER 34
# [                                           Unnamed: 0  \
# 0                                                 NaN
# 1                                         Description
# 2                                                 NaN
# 3                            Driving factors and sce-
# 4                                              narios
# 5                                                 NaN
# 6                             Example situations that
# 7                            are considered distract-
# 8                           ing e.g. unexpected radio
# 9                            volume increase or warn-
# 10                             ing message - fuel low
# 11                           Example for unavailabil-
# 12                          ity of a driver assisting
# 13                               system that does not
# 14                          affect the safe operation
# 15                                     of the vehicle
# 16                             Example for unintended
# 17                            closing of window while
# 18                                            driving
# 19                                Example for blocked
# 20                           steering column when ac-
# 21                         celerating from standstill
# 22                         Example for failure of ABS
# 23                           during emergency braking
# 24                             Example for propulsion
# 25                            failure at high lateral
# 26                                       acceleration
# 27                            Example for inadvertent
# 28                             opening bus door while
# 29                             driving with passenger
# 30                                standing in doorway
# 31                             Example for failure of
# 32                                             brakes
# 33  NOTE 1For C2, a feasible test scenario in acco...
# 34  “Practical testing experience revealed that a ...
# 35  validity”. If each of the 20 data sets complie...
# 36  of confidence of 95 % which is generally accep...
# 37                   the rationale for a C2-estimate.
# 38  NOTE 2For C1 a test to provide a rationale tha...
# 39  be feasible because a large number of test sub...
# 40         Decision can be based on expert judgement.
# 41  NOTE 3As no controllability is assumed for cat...
# 42                             such a classification.
# 43  NOTE 4The informative examples in Table B.6 ca...
# 44                                case-by-case basis.
#
#                  Unnamed: 1 Unnamed: 2  \
# 0                       NaN         C0
# 1   Controllable in general        NaN
# 2                       NaN        NaN
# 3           Controllable in        NaN
# 4                   general        NaN
# 5                       NaN        NaN
# 6                       NaN        NaN
# 7                       NaN        NaN
# 8         Maintain intended        NaN
# 9              driving path        NaN
# 10                      NaN        NaN
# 11                      NaN        NaN
# 12                      NaN        NaN
# 13        Maintain intended        NaN
# 14             driving path        NaN
# 15                      NaN        NaN
# 16                      NaN        NaN
# 17                      NaN          —
# 18                      NaN        NaN
# 19                      NaN        NaN
# 20                      NaN          —
# 21                      NaN        NaN
# 22                      NaN        NaN
# 23                      NaN          —
# 24                      NaN        NaN
# 25                      NaN          —
# 26                      NaN        NaN
# 27                      NaN        NaN
# 28                      NaN        NaN
# 29                      NaN          —
# 30                      NaN        NaN
# 31                      NaN        NaN
# 32                      NaN          —
# 33                      NaN        NaN
# 34                      NaN        NaN
# 35                      NaN        NaN
# 36                      NaN        NaN
# 37                      NaN        NaN
# 38                      NaN        NaN
# 39                      NaN        NaN
# 40                      NaN        NaN
# 41                      NaN        NaN
# 42                      NaN        NaN
# 43                      NaN        NaN
# 44                      NaN        NaN
#
#                Class of controllability (see Table 3)
# 0                                            C1 C2 C3
# 1   Simply controllable Normally control- lable Di...
# 2   More than 99 % of Between 90 % an 99 % of the ...
# 3   the average drivers average drivers or the ave...
# 4   or other traffic par- ticipants are able to ot...
# 5   avoid harm ticipants are able to avoid harm ti...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                               — — —
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                              — — —
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                Remove arm from — —
# 18                                             window
# 19                                                NaN
# 20                             Brake to slow/stop — —
# 21                                            vehicle
# 22                                  Maintain intended
# 23                                     — driving path
# 24                                                NaN
# 25                              — Maintain intended —
# 26                                       driving path
# 27                                                NaN
# 28                                    Passenger grabs
# 29                             — hand rail to avoid —
# 30                                 falling out of bus
# 31                                    Steer away from
# 32                        — — objects in driving path
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN  ] PAGE NUMBER 35
# [                                           Unnamed: 0  \
# 0                                                 NaN
# 1                                         Description
# 2                                                 NaN
# 3                           Example for faulty driver
# 4                           airbag release when trav-
# 5                                elling at high speed
# 6                                                 NaN
# 7                                                 NaN
# 8                               Example for excessive
# 9                                trailer swing during
# 10                              braking potential for
# 11                                         jacknifing
# 12                                                NaN
# 13                          Example for function with
# 14                              high automation where
# 15                          driver is not in the loop
# 16  NOTE 1For C2, a feasible test scenario in acco...
# 17  “Practical testing experience revealed that a ...
# 18  validity”. If each of the 20 data sets complie...
# 19  of confidence of 95 % which is generally accep...
# 20                   the rationale for a C2-estimate.
# 21  NOTE 2For C1 a test to provide a rationale tha...
# 22  be feasible because a large number of test sub...
# 23         Decision can be based on expert judgement.
# 24  NOTE 3As no controllability is assumed for cat...
# 25                             such a classification.
# 26  NOTE 4The informative examples in Table B.6 ca...
# 27                                case-by-case basis.
#
#                  Unnamed: 1 Unnamed: 2  \
# 0                       NaN         C0
# 1   Controllable in general        NaN
# 2                       NaN        NaN
# 3                       NaN        NaN
# 4                       NaN          —
# 5                       NaN        NaN
# 6                       NaN        NaN
# 7                       NaN        NaN
# 8                       NaN        NaN
# 9                       NaN        NaN
# 10                      NaN          —
# 11                      NaN        NaN
# 12                      NaN        NaN
# 13                      NaN        NaN
# 14                      NaN          —
# 15                      NaN        NaN
# 16                      NaN        NaN
# 17                      NaN        NaN
# 18                      NaN        NaN
# 19                      NaN        NaN
# 20                      NaN        NaN
# 21                      NaN        NaN
# 22                      NaN        NaN
# 23                      NaN        NaN
# 24                      NaN        NaN
# 25                      NaN        NaN
# 26                      NaN        NaN
# 27                      NaN        NaN
#
#                Class of controllability (see Table 3)
# 0                                            C1 C2 C3
# 1   Simply controllableNormally control- lable Dif...
# 2                                   Maintain intended
# 3                               driving path, stay in
# 4                                        — — lane, or
# 5                                  brake to slow/stop
# 6                                             vehicle
# 7                                        Driver coun-
# 8                                      ter-steers and
# 9                                    brakes in an at-
# 10                              — — tempt to maintain
# 11                                   intended driving
# 12                                               path
# 13                                      No attempt to
# 14                              — — maintain intended
# 15                                       driving path
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN  ] PAGE NUMBER 36
# [] PAGE NUMBER 37
# [] PAGE NUMBER 38
# [] PAGE NUMBER 39
# [] PAGE NUMBER 40
# [] PAGE NUMBER 41
# Error from tabula-java:
# Exception in thread "main" java.lang.IndexOutOfBoundsException: Page number does not exist.
# 	at technology.tabula.ObjectExtractor.extractPage(ObjectExtractor.java:19)
# 	at technology.tabula.PageIterator.next(PageIterator.java:30)
# 	at technology.tabula.CommandLineApp.extractFile(CommandLineApp.java:161)
# 	at technology.tabula.CommandLineApp.extractFileTables(CommandLineApp.java:124)
# 	at technology.tabula.CommandLineApp.extractTables(CommandLineApp.java:106)
# 	at technology.tabula.CommandLineApp.main(CommandLineApp.java:76)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [41], in <cell line: 10>()
#       8 print(page_count)
#      10 for i in range(0, (len(f))):
# ---> 11     df = tabula.read_pdf(f, pages= i,multiple_tables=True)
#      12 # in order to print first 5 lines of Table
#      13     print(df,"PAGE NUMBER",i+1)
#
# File ~\Anaconda3\lib\site-packages\tabula\io.py:322, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     317     raise ValueError(
#     318         "{} is empty. Check the file, or download it manually.".format(path)
#     319     )
#     321 try:
# --> 322     output = _run(java_options, kwargs, path, encoding)
#     323 finally:
#     324     if temporary:
#
# File ~\Anaconda3\lib\site-packages\tabula\io.py:80, in _run(java_options, options, path, encoding)
#      77     args.append(path)
#      79 try:
# ---> 80     result = subprocess.run(
#      81         args,
#      82         stdout=subprocess.PIPE,
#      83         stderr=subprocess.PIPE,
#      84         stdin=subprocess.DEVNULL,
#      85         check=True,
#      86     )
#      87     if result.stderr:
#      88         logger.warning("Got stderr: {}".format(result.stderr.decode(encoding)))
#
# File ~\Anaconda3\lib\subprocess.py:528, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     526     retcode = process.poll()
#     527     if check and retcode:
# --> 528         raise CalledProcessError(retcode, process.args,
#     529                                  output=stdout, stderr=stderr)
#     530 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['java', '-Dfile.encoding=UTF8', '-jar', 'C:\\Users\\XJS09914403\\Anaconda3\\lib\\site-packages\\tabula\\tabula-1.0.5-jar-with-dependencies.jar', '--pages', '41', '--guess', '--format', 'JSON', 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-3.pdf']' returned non-zero exit status 1.

# %%
import tabula
# readinf the PDF file that contain Table Data
# you can find find the pdf file with complete code in below
# read_pdf will save the pdf table into Pandas 
f = "C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-4.pdf"
doc = fitz.open(f)
page_count = len(doc)
print(page_count)

for i in range(0, (len(f))):
    df = tabula.read_pdf(f, pages= i,multiple_tables=True)
    for j in df:
        df1 = j.astype(str)
        #print(type(j))
        print(type(df1))

        #print(df1,"PAGE NUMBER",i)
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 44
# <class 'pandas.core.frame.DataFrame'>

# %%
import tabula
# readinf the PDF file that contain Table Data
# you can find find the pdf file with complete code in below
# read_pdf will save the pdf table into Pandas 
f = "C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-4.pdf"
doc = fitz.open(f)
page_count = len(doc)
print(page_count)
pattern = re.compile(input("Enter_the_text_to_Search_here"))
for i in range(0, (len(f))):
    df = tabula.read_pdf(f, pages= i,multiple_tables=True)
    for j in df:
        df1 = j.astype(str)
        print(type(df1))
        if pattern.search(df1):
            print("Found this text in the table on page",i)
# Out:
# 44
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [35], in <cell line: 9>()
#       7 page_count = len(doc)
#       8 print(page_count)
# ----> 9 pattern = re.compile(input("Enter_the_text_to_Search_here"))
#      10 for i in range(0, (len(f))):
#      11     df = tabula.read_pdf(f, pages= i,multiple_tables=True)
#
# File ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# import required module
import os
import re
import PyPDF2 
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test'
# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
for filename in os.listdir(directory):
    if not filename.startswith('~$') and filename.endswith('.pdf'):
        f = os.path.join(directory, filename)
        doc = fitz.open(f)
        page_count = len(doc)
        #print(page_count)
        for i in range(0, (len(f))):
            df = tabula.read_pdf(f, pages= i,multiple_tables=True)
            df1 = str(df)
# in order to print first 5 lines of Table
            
            if pattern.search(df1):
                
                print("Found this text in the table on page",i+1, "from the file :", filename)
# Out:
# Enter_the_text_to_Search_hereEvaluation of the tool development process in accordance with
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Error from tabula-java:
# Exception in thread "main" java.lang.IndexOutOfBoundsException: Page number does not exist.
# 	at technology.tabula.ObjectExtractor.extractPage(ObjectExtractor.java:19)
# 	at technology.tabula.PageIterator.next(PageIterator.java:30)
# 	at technology.tabula.CommandLineApp.extractFile(CommandLineApp.java:161)
# 	at technology.tabula.CommandLineApp.extractFileTables(CommandLineApp.java:124)
# 	at technology.tabula.CommandLineApp.extractTables(CommandLineApp.java:106)
# 	at technology.tabula.CommandLineApp.main(CommandLineApp.java:76)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [7], in <cell line: 10>()
#      15         #print(page_count)
#      16         for i in range(0, (len(f))):
# ---> 17             df = tabula.read_pdf(f, pages= i,multiple_tables=True)
#      18             df1 = str(df)
#      19 # in order to print first 5 lines of Table
#
# File ~\Anaconda3\lib\site-packages\tabula\io.py:322, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     317     raise ValueError(
#     318         "{} is empty. Check the file, or download it manually.".format(path)
#     319     )
#     321 try:
# --> 322     output = _run(java_options, kwargs, path, encoding)
#     323 finally:
#     324     if temporary:
#
# File ~\Anaconda3\lib\site-packages\tabula\io.py:80, in _run(java_options, options, path, encoding)
#      77     args.append(path)
#      79 try:
# ---> 80     result = subprocess.run(
#      81         args,
#      82         stdout=subprocess.PIPE,
#      83         stderr=subprocess.PIPE,
#      84         stdin=subprocess.DEVNULL,
#      85         check=True,
#      86     )
#      87     if result.stderr:
#      88         logger.warning("Got stderr: {}".format(result.stderr.decode(encoding)))
#
# File ~\Anaconda3\lib\subprocess.py:528, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     526     retcode = process.poll()
#     527     if check and retcode:
# --> 528         raise CalledProcessError(retcode, process.args,
#     529                                  output=stdout, stderr=stderr)
#     530 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['java', '-Dfile.encoding=UTF8', '-jar', 'C:\\Users\\XJS09914403\\Anaconda3\\lib\\site-packages\\tabula\\tabula-1.0.5-jar-with-dependencies.jar', '--pages', '45', '--guess', '--format', 'JSON', 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test\\ISO_26262-1.pdf']' returned non-zero exit status 1.
