# %%
# Function to convert  
def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    
    # return string  
    return str1

# %%
# Function to convert  
def listToString1(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele+" "  
    
    # return string  
    return str1

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
def TextExtraction(page_count):
    for i in range(5, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        EmptyList.append(text)
    return EmptyList

# %%
def EndDigits(i,firstElement):
    last_char=i.rpartition('.')[-1]
    #print('Last character : ', last_char)
    last_char = int(last_char)
    last_char = last_char+1
    last_char = str(last_char)
    end  = firstElement+last_char
    #print(end)
    return end

# %%
def TextExtraction(page_count):
    for i in range(5, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        EmptyList.append(text)
    return EmptyList

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
def textt( listx , i ):
    try:
        for i in listx:
            partitioned_string = i.partition('..')
            #print(partitioned_string)
            before_first_period = partitioned_string[0]
            #print(before_first_period)
            res1.append(before_first_period)
                                        
        return res1
    except ValueError:
        return ""

# %%
def unique(list1):
 
    # insert the list to the set
    list_set = set(list1)
    # convert the set to the list
    unique_list = (list_set)
    for x in unique_list:
        #print(x)
        return unique_list

# %%
from IPython.display import HTML

# %%
import json

# %%
def render_pivot_table(json_component):
    layout = '''
      <script src="https://cdn.flexmonster.com/flexmonster.js"></script>
      <h1>Flexmonster Integration with Jupyter Notebook</h1>
      <div id="pivot-container"></div>
      <script>
      new Flexmonster({0});
      </script>
      '''.format(json_component)
    return HTML(layout)

# %%
# import required module
import os
import re
import pandas as pd
import fitz
import numpy as np
from IPython.display import HTML
import json

# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-6.pdf'
EmptyList = []
res1 = []
# iterate over files in
# that directory
inputText = input("Enter_the_text_to_Search_here")
inputTList = [inputText]
#BigFun(inputText)
pattern = re.compile(inputText)
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    EmptyList = TextExtraction(page_count)
    EmptyList = listToString1(EmptyList)
    
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        if pattern.search(text):
        #print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                #print(substring)
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                #print("this is list",list)
                T = listToString(list[-1])
                #print(T)
                pat = re.compile(T+".\d+\s"+"Work products")
                found3 = re.finditer(pat, EmptyList)
                #print(found3)
                pattt = re.compile(T+".\d+\s"+"Requirements and recommendations")
                list1 = pat.findall(EmptyList)
                listR = pattt.findall(EmptyList)
                WorkR = listToString(listR)
                WorkP = listToString(list1)
                textt = EmptyList[EmptyList.index(WorkR)+len(WorkR):EmptyList.index(WorkP)]
                #print(textt)
                PR = re.compile(r'\d+.\d+')
                list4 = PR.findall(WorkP)
                #print("this is list4",list4)
                for item in found3:
                    s = item.start()
                    e = item.end()
                    substring3 = EmptyList[s:e+300]
                    #print(substring3)
                    p = re.compile(r'\d+.\d+.\d+')
                    list2 = p.findall(str(substring3))
                    TTT = listToString1(list2)
                    twoDigits = listToString(list4)
                    #print("this is 2 digi",twoDigits)
                    #print("this is TTT",TTT)
                    pp = re.compile(twoDigits+".\d")
                    Numbers = pp.findall(TTT)
                    #print("Numbers",Numbers)
                    for x in Numbers:
                        list2.remove(x)
                    #print(list2)
                    this = listToString(list2[-1])
                    
                    NewPat = re.compile(r'\d+.\d+.')
                    list9 = NewPat.findall(this)
                    #print(list9)
                    firstElement = listToString(list9)
                    #print(firstElement)
                    
                    for i in list2:
                        ListR = []
                        print(i)
                        start = i
                        end = EndDigits(i,firstElement)
                        print("this is the end",end)
                        Result = find_between( textt, start, end)
                        #print(len(Result))
                        ListR.append(Result)
                        print(ListR)
# Out:
# Enter_the_text_to_Search_hereSoftware architectural design
# 7.4.1
# this is the end 7.4.2
# ...

# %%
# import required module
import os
import re
import pandas as pd
import fitz
import numpy as np
from IPython.display import HTML
import json

# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-6.pdf'
EmptyList = []
res1 = []
# iterate over files in
# that directory
inputText = input("Enter_the_text_to_Search_here")
inputTList = [inputText]
#BigFun(inputText)
pattern = re.compile(inputText)
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    EmptyList = TextExtraction(page_count)
    EmptyList = listToString1(EmptyList)
    
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        if pattern.search(text):
        #print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                #print(substring)
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                #print("this is list",list)
                T = listToString(list[-1])
                #print(T)
                pat = re.compile(T+".\d+\s"+"Work products")
                found3 = re.finditer(pat, EmptyList)
                #print(found3)
                pattt = re.compile(T+".\d+\s"+"Requirements and recommendations")
                list1 = pat.findall(EmptyList)
                listR = pattt.findall(EmptyList)
                WorkR = listToString(listR)
                WorkP = listToString(list1)
                textt = EmptyList[EmptyList.index(WorkR)+len(WorkR):EmptyList.index(WorkP)]
                #print(textt)
                PR = re.compile(r'\d+.\d+')
                list4 = PR.findall(WorkP)
                #print("this is list4",list4)
                for item in found3:
                    s = item.start()
                    e = item.end()
                    substring3 = EmptyList[s:e+300]
                    #print(substring3)
                    p = re.compile(r'\d+.\d+.\d+')
                    list2 = p.findall(str(substring3))
                    TTT = listToString1(list2)
                    twoDigits = listToString(list4)
                    #print("this is 2 digi",twoDigits)
                    #print("this is TTT",TTT)
                    pp = re.compile(twoDigits+".\d")
                    Numbers = pp.findall(TTT)
                    #print("Numbers",Numbers)
                    for x in Numbers:
                        list2.remove(x)
                    #print(list2)
                    this = listToString(list2[-1])
                    
                    NewPat = re.compile(r'\d+.\d+.')
                    list9 = NewPat.findall(this)
                    #print(list9)
                    firstElement = listToString(list9)
                    #print(firstElement)
                    
                    LResult= []
                    for i in list2:
                        print(i)
                        start = i
                        end = EndDigits(i,firstElement)
                        if textt.find(end) == -1:
                            end = twoDigits
                        else:
                            end = EndDigits(i,firstElement)
                                
                        Result = find_between( textt, start, end)
                        #print(Result)
                        LResult.append(Result)
                print(len(LResult))
                df = pd.DataFrame()
                df["col1"] = LResult
                print(df)
# Out:
# Enter_the_text_to_Search_hereSoftware architectural design
# 7.4.1
# 7.4.13
# 7.4.10
# 7.4.11
# 4
#                                                 col1
# 0   \nTo avoid systematic faults in the software ...
# 1   An upper estimation of required resources for...
# 2   Safety-oriented analysis shall be carried out...
# 3   If the implementation of software safety requ...
# 7.4.1
# 7.4.13
# 7.4.10
# 7.4.11
# 4
#                                                 col1
# 0   \nTo avoid systematic faults in the software ...
# 1   An upper estimation of required resources for...
# 2   Safety-oriented analysis shall be carried out...
# 3   If the implementation of software safety requ...
# 4
#                                                 col1
# 0   \nTo avoid systematic faults in the software ...
# 1   An upper estimation of required resources for...
# 2   Safety-oriented analysis shall be carried out...
# 3   If the implementation of software safety requ...
# 4
# ...

# %% [markdown]
# # Please dont go crazy this time

# %%
# import required module
import os
import re
import pandas as pd
import fitz
import numpy as np
from IPython.display import HTML
import json

# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-6.pdf'
EmptyList = []
res1 = []
# iterate over files in
# that directory
inputText = input("Enter_the_text_to_Search_here")
inputTList = [inputText]
#BigFun(inputText)
pattern = re.compile(inputText)
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    EmptyList = TextExtraction(page_count)
    EmptyList = listToString1(EmptyList)
    
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        if pattern.search(text):
        #print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                #print(substring)
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                #print("this is list",list)
                T = listToString(list[-1])
                #print(T)
                pat = re.compile(T+".\d+\s"+"Work products")
                found3 = re.finditer(pat, EmptyList)
                #print(found3)
                pattt = re.compile(T+".\d+\s"+"Requirements and recommendations")
                list1 = pat.findall(EmptyList)
                listR = pattt.findall(EmptyList)
                WorkR = listToString(listR)
                WorkP = listToString(list1)
                textt = EmptyList[EmptyList.index(WorkR)+len(WorkR):EmptyList.index(WorkP)]
                #print(textt)
                PR = re.compile(r'\d+.\d+')
                list4 = PR.findall(WorkP)
                #print("this is list4",list4)
                for item in found3:
                    s = item.start()
                    e = item.end()
                    substring3 = EmptyList[s:e+300]
                    #print(substring3)
                    p = re.compile(r'\d+.\d+.\d+')
                    list2 = p.findall(str(substring3))
                    TTT = listToString1(list2)
                    twoDigits = listToString(list4)
                    #print("this is 2 digi",twoDigits)
                    #print("this is TTT",TTT)
                    pp = re.compile(twoDigits+".\d")
                    Numbers = pp.findall(TTT)
                    #print("Numbers",Numbers)
                    for x in Numbers:
                        list2.remove(x)
                    #print(list2)
                    this = listToString(list2[-1])
                    
                    NewPat = re.compile(r'\d+.\d+.')
                    list9 = NewPat.findall(this)
                    #print(list9)
                    firstElement = listToString(list9)
                    #print(firstElement)
                    j = 1
                    while j < (len(list2)):
                        inputTList.append(inputText)
                        j += 1
                    #print(inputTList)
                    LResult= []
                    for i in list2:
                        #print(i)
                        start = i
                        end = EndDigits(i,firstElement)
                        if textt.find(end) == -1:
                            end = twoDigits
                        else:
                            end = EndDigits(i,firstElement)
                                
                        Result = find_between( textt, start, end)
                        #print(Result)
                        LResult.append(Result)
                #print(len(LResult))
            df = pd.DataFrame((zip(inputTList,LResult)), columns =['chapterName','Requirements'])
            #print("this is the length",len(df))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [104], in <cell line: 17>()
#      14 res1 = []
#      15 # iterate over files in
#      16 # that directory
# ---> 17 inputText = input("Enter_the_text_to_Search_here")
#      18 inputTList = [inputText]
#      19 #BigFun(inputText)
#
# File ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# ...

# %% [markdown]
# # this works dont touch it

# %% [markdown]
# # Create a collable function for the second types of documents

# %%
def bigfunction(inputText):
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        if pattern.search(text):
        #print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                #print(substring)
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                #print("this is list",list)
                T = listToString(list[-1])
                #print(T)
                pat = re.compile(T+".\d+\s"+"Work products")
                found3 = re.finditer(pat, EmptyList)
                #print(found3)
                pattt = re.compile(T+".\d+\s"+"Requirements and recommendations")
                list1 = pat.findall(EmptyList)
                listR = pattt.findall(EmptyList)
                WorkR = listToString(listR)
                WorkP = listToString(list1)
                textt = EmptyList[EmptyList.index(WorkR)+len(WorkR):EmptyList.index(WorkP)]
                #print(textt)
                PR = re.compile(r'\d+.\d+')
                list4 = PR.findall(WorkP)
                #print("this is list4",list4)
                for item in found3:
                    s = item.start()
                    e = item.end()
                    substring3 = EmptyList[s:e+240]
                    print(substring3)
                    p = re.compile(r'\d+.\d+.\d+')
                    list2 = p.findall(str(substring3))
                    print(list2)
                    A = []   
                    for i in list2:
                        i = i.replace("\t","")
                        A.append(i)
                    print("this is aletered list",A)
                        
                    #print("this is list2",list2)
                        
                    #print("this is list2",list2)
                    TTT = listToString1(A)
                    twoDigits = listToString(list4)
                    #print("this is 2 digi",twoDigits)
                    #print("this is TTT",TTT)
                    pp = re.compile(twoDigits+".\d")
                    Numbers = pp.findall(TTT)
                    print(Numbers)
                    #print("Numbers",Numbers)
                    for x in Numbers:
                        A.remove(x)
                    print(A)
                    this = listToString(A[-1])
                    
                    NewPat = re.compile(r'\d+.\d+.')
                    list9 = NewPat.findall(this)
                    #print(list9)
                    firstElement = listToString(list9)
                    #print(firstElement)
                    j = 1
                    while j < (len(A)):
                        inputTList.append(inputText)
                        j += 1
                    #print(inputTList)
                    LResult= []
                    for i in A:
                        print(i)
                        start = i
                        end = EndDigits(i,firstElement)
                        if textt.find(end) == -1:
                            end = twoDigits
                        else:
                            end = EndDigits(i,firstElement)
                                
                        Result = find_between( textt, start, end)
                        #print(Result)
                        LResult.append(Result)
                #print(len(LResult))
                        df = pd.DataFrame((zip(inputTList,LResult)), columns =['chapterName','Requirements'])
                    print(df)
                    return df

            #print(df)

# %%
# import required module
import os
import re
import pandas as pd
import fitz
import numpy as np
from IPython.display import HTML
import json

# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-4.pdf'
EmptyList = []
res1 = []
# iterate over files in
# that directory
inputText = input("Enter_the_text_to_Search_here")
inputTList = [inputText]
#BigFun(inputText)
pattern = re.compile(inputText)
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    EmptyList = TextExtraction(page_count)
    EmptyList = listToString1(EmptyList)
df = bigfunction(inputText)
df
json_data = df.to_json(orient='records')
flexmonster = {
    "container": "#pivot-container",
    "componentFolder": "https://cdn.flexmonster.com/",
    "width": "100%",
    "height": 430,
    "toolbar": True,
    "report": {
        "dataSource": {
            "type": "json",
            "data": json.loads(json_data) # decoding JSON
        },
        "slice": {
        "reportFilters": [
            {
                "uniqueName": "Date.Year",
                "filter": {
                    "members": [
                        "date.year.[2018]"
                    ]
                }
            },
            {
                "uniqueName": "Date.Month",
                "filter": {
                    "members": [
                        "date.month.[january]"
                    ]
                }
            }
        ],
        "rows": [
            {
                "uniqueName": "Name"
            },
            {
                "uniqueName": "Age"
            },
            {
                "uniqueName": "score"
            }
            
        ],
        "columns": [
            {
                "uniqueName": "[Measures]"
            }
        ],
        
        "sorting": {
            "column": {
                "type": "desc",
                "tuple": [],
            }
        }
    },
        
    "options": {
        "grid": {
            "type": "flat",
            "showTotals": "off",
            "showGrandTotals": "off"
        }
    },
    "formats": [
        {
            "name": "",
           
        }
    ]
}
}
flexmonster_json_object = json.dumps(flexmonster)
render_pivot_table(flexmonster_json_object)
# Out:
# Enter_the_text_to_Search_hereVehicle integration and testing
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [100], in <cell line: 29>()
#      27 df = bigfunction(inputText)
#      28 df
# ---> 29 json_data = df.to_json(orient='records')
#      30 flexmonster = {
#      31     "container": "#pivot-container",
#      32     "componentFolder": "https://cdn.flexmonster.com/",
#    (...)
#      99 }
#     100 }
#     101 flexmonster_json_object = json.dumps(flexmonster)
#
# AttributeError: 'NoneType' object has no attribute 'to_json'

# %% [markdown]
# # fIRST TYPE OF DOCUMENTS

# %%
def BigFun(inputText):
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        if pattern.search(text):
            #print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                 
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                
                T = listToString(list[-1])
                TT = (int(T))
                TT= TT+1
                TT = (str(TT))
                pat = re.compile(T+".\d+\s"+"Work products")
                for i in range(0, page_count):
                    page = doc[i]
                    text = page.get_text("text")
                    list1 = pat.findall(str(text))
                    found3 = re.finditer(pat, text)
                    res = []
                    for i in list1:
                        if i:
                            res.append(i)
                            resultFound = listToString(res)
                        #print("Work Products:", resultFound)
                            PR = re.compile(r'\d+.\d+')
                            
                            list4 = PR.findall(str(resultFound))
                            print("this",list4)
                            twoDigits = listToString1(list4)
                            for item in found3:
                                s = item.start()
                                e = item.end()
                                substring3 = text[s:e+300]
                                #print(substring3.split(TT)[0])
                                p = re.compile(r'\d+.\d+.\d+')
                                list2 = p.findall(str(substring3))
                                #print("THIS LIST RIGHT HERE",list2)
                                TTT = listToString1(list2)
                                #print("this is the list of digits:",TTT)
                                wp = listToString(list4)
                                Num = wp
                                #print(Num)
                                Numbers = re.findall(Num+".\d", TTT)
                                #print(type(Numbers))
                                
                                TTTT = listToString1(Numbers)
                                for x in Numbers:
                                    #print(x)
                                    list2.remove(x)
                                #print(list2)
                                for x in list2:
                                    patternWP = re.compile(x+"\s+.*\.")
                                    for i in range(0, 5):
                                        page = doc[i]
                                        text = page.get_text("text")
                                        list6 = patternWP.findall(str(text))
                                    #print("THIS IS LIST6",list6)
                                        list6 = textt(list6 , i )
                                        list6 = unique(list6)
                                        j = 1
                                    print("this is list6",list6)
                                    while j < (len(list6)):
                                        inputTList.append(inputText)
                                    #print(inputTList)
                                        j += 1
                                    print("this is THE CHAPTER NAME",inputTList)
                                    l = []
                                    for i in list6:
                                        l.append(i)
                                    NewPat = re.compile(r'\d+.\d+.')
                                    list9 = NewPat.findall(i)
                                    firstElement = list9[0]
                                    print("this is the first element",firstElement)
                                    l2 = []
                                    for i in l:
                                    #print(i)
                                        patternR = re.compile(r'\d+.\d+.\d+')
                                        list5 = patternR.findall(i)
                                    #print(type(list5))
                                        l2.append(list5)
                                    #print(type(l2))
                                    res = [''.join(ele) for ele in l2]
                                    print(res)
                                    LResult= []
                                    for i in res:
                                        start = i
                                        end = EndDigits(i,firstElement)
                                        if EmptyList.find(end) == -1:
                                            end = twoDigits
                                        else:
                                            end = EndDigits(i,firstElement)
                                
                                        Result = find_between( EmptyList, start, end)
                                        LResult.append(Result)
                                print(LResult)
                                df = pd.DataFrame((zip(inputTList,l,LResult)), columns =['chapterName','Requirements','SubRequirements'])
                                print(type(df))
                                return df

# %%
# import required module
import os
import re
import pandas as pd
import fitz
import numpy as np
from IPython.display import HTML
import json

# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-12_Dez.-2018.pdf'
EmptyList = []
res1 = []
# iterate over files in
# that directory
inputText = input("Enter_the_text_to_Search_here")
inputTList = [inputText]
#BigFun(inputText)
pattern = re.compile(inputText)
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    EmptyList = TextExtraction(page_count)
    EmptyList = listToString1(EmptyList)
df = BigFun(inputText)
print(df)
json_data = df.to_json(orient='records')
flexmonster = {
    "container": "#pivot-container",
    "componentFolder": "https://cdn.flexmonster.com/",
    "width": "100%",
    "height": 430,
    "toolbar": True,
    "report": {
        "dataSource": {
            "type": "json",
            "data": json.loads(json_data) # decoding JSON
        },
        "slice": {
        "reportFilters": [
            {
                "uniqueName": "Date.Year",
                "filter": {
                    "members": [
                        "date.year.[2018]"
                    ]
                }
            },
            {
                "uniqueName": "Date.Month",
                "filter": {
                    "members": [
                        "date.month.[january]"
                    ]
                }
            }
        ],
        "rows": [
            {
                "uniqueName": "Name"
            },
            {
                "uniqueName": "Age"
            },
            {
                "uniqueName": "score"
            }
            
        ],
        "columns": [
            {
                "uniqueName": "[Measures]"
            }
        ],
        
        "sorting": {
            "column": {
                "type": "desc",
                "tuple": [],
            }
        }
    },
        
    "options": {
        "grid": {
            "type": "flat",
            "showTotals": "off",
            "showGrandTotals": "off"
        }
    },
    "formats": [
        {
            "name": "",
           
        }
    ]
}
}
flexmonster_json_object = json.dumps(flexmonster)
render_pivot_table(flexmonster_json_object)
# Out:
# Enter_the_text_to_Search_hereSafety validation
# this ['10.5']
# this is list6 {'10.4.1 Safety validation environment '}
# this is THE CHAPTER NAME ['Safety validation']
# this is the first element 10.4.
# ['10.4.1']
# this is list6 {'10.4.2 Specification of safety validation ', '10.4.1 Safety validation environment '}
# this is THE CHAPTER NAME ['Safety validation', 'Safety validation']
# this is the first element 10.4.
# ['10.4.2', '10.4.1']
# this is list6 {'10.4.2 Specification of safety validation ', '10.4.3 Execution of safety validation ', '10.4.1 Safety validation environment '}
# this is THE CHAPTER NAME ['Safety validation', 'Safety validation', 'Safety validation', 'Safety validation']
# this is the first element 10.4.
# ['10.4.2', '10.4.3', '10.4.1']
# this is list6 {'10.4.2 Specification of safety validation ', '10.4.3 Execution of safety validation ', '10.4.4 Evaluation ', '10.4.1 Safety validation environment '}
# ...
