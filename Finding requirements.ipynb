# %%
# import required module
import os
import re
#import PyPDF2 
import fitz
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-12_Dez.-2018.pdf'

# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        #print(type(text))
        #print(text)
        if pattern.search(text):
            #print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                #print(substring)
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                #print(list[-1])
                T = listToString(list[-1])
                TT = (int(T))
                TT= TT+1
                TT = (str(TT))
                #print(type(TT))
                pat = re.compile(T+".\d+\s"+"Work products")
                for i in range(0, page_count):
                    page = doc[i]
                    text = page.get_text("text")
                    list1 = pat.findall(str(text))
                    found3 = re.finditer(pat, text)
                    #print(list1)
                    res = []
                    for i in list1:
                        if i:
                            res.append(i)
                            #print(res)
                            resultFound = listToString(res)
                            #print("Work Products:", resultFound)
                            PR = re.compile(r'\d+.\d+')
                            
                            list4 = PR.findall(str(resultFound))
                            
                            
                            
                            
                            for item in found3:
                                s = item.start()
                                e = item.end()
                                substring3 = text[s:e+300]
                                #print(substring3.split(TT)[0])
                                p = re.compile(r'\d+.\d+.\d+')
                                list2 = p.findall(str(substring3))
                                #print(list2)
                                TTT = listToString1(list2)
                                #print("this is the list of digits:",TTT)
                                wp = listToString(list4)
                                Num = wp
                                print("num" ,Num)
                                Numbers = re.findall(Num+".\d", TTT)
                                #print(type(Numbers))
                                
                                TTTT = listToString1(Numbers)
                                #print(TTTT)
                                for x in Numbers:
                                    #print(x)
                                    list2.remove(x)
                                #print(list2)
                                for x in list2:
                                    patternWP = re.compile(x+"\s+.*\.")
                                    for i in range(0, 5):
                                        page = doc[i]
                                        text = page.get_text("text")
                                        list6 = patternWP.findall(str(text))
                                        #print(list6)
                                        res1 = []
                                        for i in list6:
                                            if i:
                                                res1.append(i)
                                                #print(res1)
                                                resultFound = listToString(res1)
                                                for i in res1:
                                                    patternR = re.compile(r'\d+.\d+.\d+')
                                                    list5 = patternR.findall(i)
                                                    #print(list5)
                                                    for i in list5:
                                                        print(i)
                                                        last_char = i[-1]
                                                        #print('Last character : ', last_char)
                                                        last_char = int(last_char)
                                                        last_char = last_char+1
                                                        last_char = str(last_char)
                                                        #print(type(last_char))
                                                        #pat = re.compile(r'\d+.\d+')
                                                        #list8 = pat.findall(i)
                                                        
                                                        
                                                            
                                                        
                                                        #number = listToString(i)
                                                    
                                                        #for j in range(0, page_count):
                                                            #page = doc[j]
                                                            #text = page.get_text("text")
                                                            #patternRR = re.compile(number+".\d")
                                                            #list7 = patternRR.findall(str(text))
                                                            #print(list7)
# Out:
# Enter_the_text_to_Search_hereSafety validation
# num 10.5
# 10.4.1
# 10.4.2
# 10.4.3
# 10.4.4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [149], in <cell line: 13>()
#      32 list = p.findall(str(substring))
#      33 #print(list[-1])
# ---> 34 T = listToString(list[-1])
#      35 TT = (int(T))
#      36 TT= TT+1
#
# IndexError: list index out of range

# %%
# Function to convert  
def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    
    # return string  
    return str1

# %%
# Function to convert  
def listToString1(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele+" "  
    
    # return string  
    return str1

# %%
# import required module
import os
import re
#import PyPDF2 
import fitz
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-12_Dez.-2018.pdf'
EmptyList = []
# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    for i in range(5, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        EmptyList.append(text)

EmptyList = listToString1(EmptyList)
#print(EmptyList)
start = '10.4.3 Execution of safety validation'
end = '10.4.4 Evaluation'
Result = find_between( EmptyList, start, end)
print(Result)
# Out:
# Enter_the_text_to_Search_hereS
#
# 10.4.3.1 If testing is used for safety validation, then the same requirements as provided for verification
# testing (see ISO 26262-8:2018, 9.4.2 and 9.4.3) may be applied.
# 10.4.3.2 The achievement of functional safety for the item when being integrated into the vehicle shall
# be validated by evaluating the following aspects:
# a) the controllability;
# NOTE 1
# Controllability can be validated using operating scenarios, including intended use and
# foreseeable misuse.
# NOTE 2
# One acceptance criterion for the safety validation might be a sufficient controllability in a safe
# state defined in ISO 26262-3:2018, 7.4.2.5.
# NOTE 3
# A single acceptance criterion might not be sufficient to verify a safe state.
# b) the effectiveness of the external measures;
# c)
# the effectiveness of the elements of other technologies; and
# d) assumptions that influence the ASIL mapped from MSIL in the hazard analysis and risk assessment
# (see 8.4.4.4) that can be checked only in the final vehicle.
# EXAMPLE
# If a mechanical component is assumed to prevent or mitigate a specific hazard potentially caused
# by a malfunction of an E/E system, the effectiveness of this component to prevent or mitigate that hazard is
# validated on vehicle level.
# 10.4.3.3 The safety validation at the vehicle level, based on the safety goals, the functional safety
# requirements and the intended use, shall be executed as planned using:
# a) the safety validation procedures and test cases for each safety goal including detailed pass/fail
# criteria; and
# b) the scope of application. This may include issues such as configuration, environmental conditions,
# riding situations, operational use cases, etc.
# NOTE
# Operational use cases can be created to help focus the safety validation at the vehicle level.
# 10.4.3.4 An appropriate set of the following methods shall be applied:
# a) repeatable tests with specified test procedures, test cases, and pass/fail criteria;
# EXAMPLE 1
# Positive tests of functions and safety requirements, black box testing, simulation, tests under
# boundary conditions, fault injection, durability tests, stress tests, highly accelerated life testing (HALT),
# simulation of external influences.
# b) analyses;
# EXAMPLE 2
# FMEA, FTA, ETA, simulation.
# c)
# long-term tests, such as vehicle driving schedules and captured test fleets;
# NOTE 1
# Long-term tests with targeted users can be infeasible for motorcycles.
# d) user tests under real-life conditions, panel or blind tests, expert panels; and
#
# 22
# © ISO 2018 – All rights reserved
# Normen-Download-Beuth-Lisa Dräxlmaier GmbH-KdNr.280437-ID.QTQDJF4FTSNOCAQV92E2EK5D.1-2019-01-23 11:04:42
#
# ISO 26262-12:2018(E)
# NOTE 2
# User test can be infeasible for motorcycles. Real-life condition can be conducted using simulated
# condition.
# e) reviews.

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
# import required module
import os
import re
#import PyPDF2 
import fitz
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-12_Dez.-2018.pdf'
EmptyList = []
# iterate over files in
# that directory
pattern = re.compile(input("Enter_the_text_to_Search_here"))
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    EmptyList = TextExtraction(page_count)
    EmptyList = listToString1(EmptyList)
    #print(EmptyList)
    for i in range(0, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        #print(type(text))
        #print(text)
        if pattern.search(text):
            #print("Found the Text on page",i+1, "from the file :", filename)
            for item in found:
                s = item.start()
                e = item.end()
                substring = text[s-100:e]
                #print(substring)
                p = re.compile(r'\d+')
                list = p.findall(str(substring))
                #print(list)
                #print(list[-1])
                T = listToString(list[-1])
                TT = (int(T))
                TT= TT+1
                TT = (str(TT))
                #print(type(TT))
                pat = re.compile(T+".\d+\s"+"Work products")
                for i in range(0, page_count):
                    page = doc[i]
                    text = page.get_text("text")
                    list1 = pat.findall(str(text))
                    found3 = re.finditer(pat, text)
                    #print(list1)
                    res = []
                    for i in list1:
                        if i:
                            res.append(i)
                            #print(res)
                            resultFound = listToString(res)
                            #print("Work Products:", resultFound)
                            PR = re.compile(r'\d+.\d+')
                            
                            list4 = PR.findall(str(resultFound))
                            print("this",list4)
                            twoDigits = listToString1(list4)
                            #print(twoDigits)
                            
                            
                            
                            
                            for item in found3:
                                s = item.start()
                                e = item.end()
                                substring3 = text[s:e+300]
                                #print(substring3.split(TT)[0])
                                p = re.compile(r'\d+.\d+.\d+')
                                list2 = p.findall(str(substring3))
                                #print(list2)
                                TTT = listToString1(list2)
                                #print("this is the list of digits:",TTT)
                                wp = listToString(list4)
                                Num = wp
                                #print(Num)
                                Numbers = re.findall(Num+".\d", TTT)
                                #print(type(Numbers))
                                
                                TTTT = listToString1(Numbers)
                                #print(TTTT)
                                for x in Numbers:
                                    #print(x)
                                    list2.remove(x)
                                #print(list2)
                                for x in list2:
                                    patternWP = re.compile(x+"\s+.*\.")
                                    for i in range(0, 5):
                                        page = doc[i]
                                        text = page.get_text("text")
                                        list6 = patternWP.findall(str(text))
                                        #print(list6)
                                        res1 = []
                                        for i in list6:
                                            partitioned_string = i.partition('..')
                                            #print(partitioned_string)
                                            before_first_period = partitioned_string[0]
                                            #print(before_first_period)
                                            res1.append(before_first_period)
                                            for i in res1:
                                                #print(i)
                                                patternR = re.compile(r'\d+.\d+.\d+')
                                                list5 = patternR.findall(i)
                                                print(list5)
                                                NewPat = re.compile(r'\d+.\d+.')
                                                list9 = NewPat.findall(i)
                                                firstElement = list9[0]
                                                #print("firstElement",type(firstElement))
                                                for i in list5:
                                                    start = i
                                                    end = EndDigits(i)
                                                    Result = find_between( EmptyList, start, end)
                                                    print(Result)
                                                    #print(Result)
                                                    if EmptyList.find(end) == -1:
                                                        start = i
                                                        end = twoDigits
                                                        print("This is the end",end)
                                                        Result = find_between( EmptyList, start, end)
                                                        print(Result)
# Out:
# Enter_the_text_to_Search_hereSafety validation
# this ['10.5']
# ['10.4.1']
# 10.4.2
#  Safety validation environment
# 10.4.1.1 The safety goals shall be validated for the item in a representative context at vehicle level.
# NOTE
# This integrated item includes, where applicable: system, software, hardware, elements of other
# technologies, external measures.
# 10.4.1.2 For the definition of a representative context, representative vehicles based on vehicle types
# and vehicle configurations shall be considered.
# NOTE
# The Hazard Analysis and Risk Assessment report might be used as a source of information regarding
# relevant input for the choice of representative vehicles (see 8.5.1).
# 10.4.1.3 Safety goals shall be validated giving consideration to variance in operation that impacts the
# technical characteristics, which have been considered in the hazard analysis and risk assessment.
#
# ['10.4.2']
# 10.4.3
# 	 Specification	of	safety	validation
# 10.4.2.1 The safety validation specification shall be defined, including:
# a) the configuration of the item subjected to safety validation including its calibration data in
# accordance with ISO 26262-6:2018, Annex C;
# NOTE
# If a complete safety validation of each item configuration is not feasible, then a reasonable subset
# can be selected.
#
# © ISO 2018 – All rights reserved
# 21
# Normen-Download-Beuth-Lisa Dräxlmaier GmbH-KdNr.280437-ID.QTQDJF4FTSNOCAQV92E2EK5D.1-2019-01-23 11:04:42
#
# ISO 26262-12:2018(E)
# b) the specification of safety validation procedures, test cases, riding manoeuvres, and acceptance
# criteria; and
# c)
# the equipment and the required environmental conditions.
#
# ['10.4.3']
# 10.4.4
#  Execution of safety validation
# 10.4.3.1 If testing is used for safety validation, then the same requirements as provided for verification
# testing (see ISO 26262-8:2018, 9.4.2 and 9.4.3) may be applied.
# 10.4.3.2 The achievement of functional safety for the item when being integrated into the vehicle shall
# be validated by evaluating the following aspects:
# a) the controllability;
# NOTE 1
# Controllability can be validated using operating scenarios, including intended use and
# foreseeable misuse.
# NOTE 2
# One acceptance criterion for the safety validation might be a sufficient controllability in a safe
# state defined in ISO 26262-3:2018, 7.4.2.5.
# NOTE 3
# A single acceptance criterion might not be sufficient to verify a safe state.
# b) the effectiveness of the external measures;
# c)
# the effectiveness of the elements of other technologies; and
# d) assumptions that influence the ASIL mapped from MSIL in the hazard analysis and risk assessment
# (see 8.4.4.4) that can be checked only in the final vehicle.
# EXAMPLE
# If a mechanical component is assumed to prevent or mitigate a specific hazard potentially caused
# by a malfunction of an E/E system, the effectiveness of this component to prevent or mitigate that hazard is
# validated on vehicle level.
# 10.4.3.3 The safety validation at the vehicle level, based on the safety goals, the functional safety
# requirements and the intended use, shall be executed as planned using:
# a) the safety validation procedures and test cases for each safety goal including detailed pass/fail
# criteria; and
# b) the scope of application. This may include issues such as configuration, environmental conditions,
# riding situations, operational use cases, etc.
# NOTE
# Operational use cases can be created to help focus the safety validation at the vehicle level.
# 10.4.3.4 An appropriate set of the following methods shall be applied:
# a) repeatable tests with specified test procedures, test cases, and pass/fail criteria;
# EXAMPLE 1
# Positive tests of functions and safety requirements, black box testing, simulation, tests under
# boundary conditions, fault injection, durability tests, stress tests, highly accelerated life testing (HALT),
# simulation of external influences.
# b) analyses;
# EXAMPLE 2
# FMEA, FTA, ETA, simulation.
# c)
# long-term tests, such as vehicle driving schedules and captured test fleets;
# NOTE 1
# Long-term tests with targeted users can be infeasible for motorcycles.
# d) user tests under real-life conditions, panel or blind tests, expert panels; and
#
# 22
# © ISO 2018 – All rights reserved
# Normen-Download-Beuth-Lisa Dräxlmaier GmbH-KdNr.280437-ID.QTQDJF4FTSNOCAQV92E2EK5D.1-2019-01-23 11:04:42
#
# ISO 26262-12:2018(E)
# NOTE 2
# User test can be infeasible for motorcycles. Real-life condition can be conducted using simulated
# condition.
# e) reviews.
#
# ['10.4.4']
# 10.4.5
#
# This is the end 10.5
#  Evaluation
# 10.4.4.1 The results of the safety validation shall be evaluated to provide evidence that the implemented
# safety goals achieve functional safety for the item.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [49], in <cell line: 13>()
#      35 list = p.findall(str(substring))
#      36 #print(list)
#      37 #print(list[-1])
# ---> 38 T = listToString(list[-1])
#      39 TT = (int(T))
#      40 TT= TT+1
#
# IndexError: list index out of range

# %%
def TextExtraction(page_count):
    for i in range(5, page_count):
        page = doc[i]
        text = page.get_text("text")
        found = re.finditer(pattern, text)
        EmptyList.append(text)
    return EmptyList

# %%
# import required module
import os
import re
#import PyPDF2 
import fitz
# assign directory
directory = 'C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/'
filename = 'ISO_26262-12_Dez.-2018.pdf'
EmptyList = []
# iterate over files in
# that directory
if not filename.startswith('~$') and filename.endswith('.pdf'):
    f = os.path.join(directory, filename)
    doc = fitz.open(f)
    page_count = len(doc)
    #print(page_count)
    EmptyList = TextExtraction(page_count)
    EmptyList = listToString1(EmptyList)
#print(EmptyList)
start = '10.4.4'
end = '10.4.5'
#final = ["10.5"]
#final.append(end)
#print(final)
if EmptyList.find("10.4.5"):
    end = "10.5"
#Result = find_between( EmptyList, start, end)
#print(Result)
index = EmptyList.find("10.4.5")
print(index)
# Out:
# -1

# %%
def EndDigits(i):
    last_char = i[-1]
    #print('Last character : ', last_char)
    last_char = int(last_char)
    last_char = last_char+1
    last_char = str(last_char)
    end  = firstElement+last_char
    print(end)
    return end
