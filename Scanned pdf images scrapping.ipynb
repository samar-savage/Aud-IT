# %%
import subprocess
import os
import uuid

# %%
# Convert PDF document to HTML with fixed positioning option turned on (default)
Convert.ToHtml("C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-7.pdf", "C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-7.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 # Convert PDF document to HTML with fixed positioning option turned on (default)
# ----> 2 Convert.ToHtml("C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-7.pdf", "C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-7.html")
#
# NameError: name 'Convert' is not defined

# %%
pip install pdf2docx
# Out:
# ...
#   Using cached pdf2docx-0.5.3-py3-none-any.whl (146 kB)
# ...
#   Using cached fire-0.4.0-py2.py3-none-any.whl
# ...
#   Using cached python_docx-0.8.11-py3-none-any.whl
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pdf2docx import Converter

# %%
cv = Converter("C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-11_Dez.-2018.pdf")
cv.convert("C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-11_Dez.-2018.docx")
cv.close()
# Out:
# [INFO] Start to convert C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-11_Dez.-2018.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [WARNING] Ignore Line "1" due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "i" due to overlap
# [WARNING] Ignore Line "1" due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "i" due to overlap
# [WARNING] Ignore Line "1" due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "i" due to overlap
# [WARNING] Ignore Line "1" due to overlap
# [WARNING] Ignore Line "," due to overlap
# [WARNING] Ignore Line "," due to overlap
# ...

# %%
pip install docx2pdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import zipfile

z = zipfile.ZipFile("C:/Users/XJS09914403/OneDrive - DRAEXLMAIER/Test/ISO_26262-7.docx")


#print all files in zip archive
all_files = z.namelist()
print(all_files)

#get all files in word/media/ directory
images = filter(lambda x: x.startswith('word/media/'), all_files)
print(images)
#open an image and save it
image1 = z.open('word/media/image1.png').read()
f = open('image1.png','wb')
# Out:
# ['[Content_Types].xml', '_rels/.rels', 'docProps/core.xml', 'docProps/app.xml', 'word/document.xml', 'word/_rels/document.xml.rels', 'word/styles.xml', 'word/stylesWithEffects.xml', 'word/settings.xml', 'word/webSettings.xml', 'word/fontTable.xml', 'word/theme/theme1.xml', 'customXml/item1.xml', 'customXml/_rels/item1.xml.rels', 'customXml/itemProps1.xml', 'word/numbering.xml', 'word/media/image1.png', 'word/media/image2.png', 'word/media/image3.png', 'word/media/image4.png', 'word/media/image5.png', 'word/media/image6.png', 'word/media/image7.png', 'word/media/image8.png', 'word/media/image9.png', 'word/media/image10.png', 'word/media/image11.png', 'word/media/image12.png', 'word/media/image13.png', 'word/media/image14.png', 'docProps/thumbnail.jpeg']
# ...
